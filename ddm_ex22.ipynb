# %%
import pickle
from ddm_utils import *
import numpy as np
import matplotlib.pyplot as plt
import re
from scipy import stats

# %%
N_sample_sizes = [500, 1000, 5000, 10000, 25000, 35000, 50000]
a = 10; v = 2; N_bads_run = 100;
ground_truths = [v, a, 0.5]
param_names = ['v', 'a', 'w']

# %% [markdown]
# #  large range
#
# ```
#     lower_bounds = np.array([-10, 0.1, 0.1])
#     upper_bounds = np.array([10, 15, 0.9])
#
#     plausible_lower_bounds = np.array([-5, 1, 0.2])
#     plausible_upper_bounds = np.array([5, 13, 0.8])
#
# ```

# %%
filename = 'vaw_bads_vals_v4_a10.pkl'
ex22_bads_plots(filename)

# %%
filename = 'vaw_bads_vals_v0_a2.pkl'
ex22_bads_plots(filename)

# %% [markdown]
# # shortening the range?
#
# ```
# lower_bounds = np.array([0.1, 0.1, 0.1])
# upper_bounds = np.array([7, 5, 0.9])
#
# plausible_lower_bounds = np.array([0.5, 1, 0.3])
# plausible_upper_bounds = np.array([5, 4, 0.7])
# ```

# %%
filename = 'vaw_bads_vals_v4_a2.pkl'
ex22_bads_plots(filename)

# %% [markdown]
# ```
# lower_bounds = np.array([0.5, 5, 0.2])
# upper_bounds = np.array([5, 15, 0.8])
#
# plausible_lower_bounds = np.array([1, 7, 0.3])
# plausible_upper_bounds = np.array([4, 12, 0.7])
# ```

# %%
filename = 'vaw_bads_vals_v2_a10.pkl'
ex22_bads_plots(filename)

# %% [markdown]
# ```
# lower_bounds = np.array([0.5, 5, 0.2])
#     upper_bounds = np.array([5, 15, 0.8])
#
#     plausible_lower_bounds = np.array([1, 8.5, 0.3])
#     plausible_upper_bounds = np.array([4, 11.5, 0.7])
# ```

# %%
filename = 'vaw_bads_vals_v2_a10.pkl'
ex22_bads_plots(filename)

# %% [markdown]
# # More close `a` values
#
# ```
# lower_bounds = np.array([0.5, 8, 0.2])
# upper_bounds = np.array([5, 12, 0.8])
#
# plausible_lower_bounds = np.array([1, 9, 0.3])
# plausible_upper_bounds = np.array([4, 11, 0.7])
# ```

# %%
filename = 'vaw_bads_vals_v2_a10.pkl'
ex22_bads_plots(filename)

# %% [markdown]
# # Different N values with narrow range
#
# ```
# lower_bounds = np.array([0.5, 8, 0.2])
# upper_bounds = np.array([5, 12, 0.8])
#
# plausible_lower_bounds = np.array([1, 9, 0.3])
# plausible_upper_bounds = np.array([4, 11, 0.7])
# ```

# %%
param_N_bads = get_param_N_bads_tensor(N_sample_sizes, a, v, N_bads_run)
ex22_bads_vs_N_plots(N_sample_sizes, param_names, ground_truths, param_N_bads)

# %% [markdown]
# # For Wide/bad range, how will it work for N?
#
# ```
# lower_bounds = np.array([0.01, 5, 0.1])
# upper_bounds = np.array([10, 15, 0.9])
#
# plausible_lower_bounds = np.array([0.5, 7, 0.2])
# plausible_upper_bounds = np.array([7, 13, 0.8])
# ```

# %%
param_N_bads = get_param_N_bads_tensor(N_sample_sizes, a, v, N_bads_run)
ex22_bads_vs_N_plots(N_sample_sizes, param_names, ground_truths, param_N_bads)

# %% [markdown]
# # TODO: Very bad range
