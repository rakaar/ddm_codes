# %%
# tensor flow
import tensorflow_probability as tfp
import tensorflow as tf

# rest
from numba import njit, jit
import matplotlib.pyplot as plt
import numpy as np
import pickle
from joblib import Parallel, delayed

# parse
from ddm_utils import simulate_ddm, parse_sim_results

# %%
N_sim = 100; v = 0.2; a = 2
sim_results = Parallel(n_jobs=-1)(delayed(simulate_ddm)(v, a) for _ in range(N_sim))


choices, RTs = parse_sim_results(sim_results)
    
with open('sample_rt.pkl', 'wb') as f:
    pickle.dump(RTs, f)
with open('sample_choice.pkl', 'wb') as f:
    pickle.dump(choices, f)

# %%
def rtd_density_a(t, v, a, w, K_max=10):
    # Use tf operations instead of numpy
    if tf.greater(t, 0.25):
        non_sum_term = (np.pi/a**2)*tf.exp(-v*a*w - (v**2 * t/2))
        k_vals = tf.linspace(1., tf.cast(K_max, tf.float32), K_max)
        sum_sine_term = tf.sin(k_vals*np.pi*w)
        sum_exp_term = tf.exp(-(k_vals**2 * np.pi**2 * t)/(2*a**2))
        sum_result = tf.reduce_sum(k_vals * sum_sine_term * sum_exp_term)
    else:
        non_sum_term = (1/a**2)*(a**3/tf.sqrt(2*np.pi*t**3))*tf.exp(-v*a*w - (v**2 * t)/2)
        K_max = int(K_max/2)
        k_vals = tf.linspace(tf.cast(-K_max, tf.float32), tf.cast(K_max, tf.float32), 2*K_max + 1)
        sum_w_term = w + 2*k_vals
        sum_exp_term = tf.exp(-(a**2 * (w + 2*k_vals)**2)/(2*t))
        sum_result = tf.reduce_sum(sum_w_term*sum_exp_term)


    density =  non_sum_term * sum_result
    density = tf.where(density <= 0, 1e-10, density) # Use tf.where for conditional assignment
    return density


def loglike_fn(v,a,w):
    # No need to convert to numpy arrays, keep them as tensors

     # Load RTs and choices from the saved files
    print(f"v,a,w: {v}, {a}, {w}")
    with open('sample_rt.pkl', 'rb') as f:
        RTs = pickle.load(f)
    with open('sample_choice.pkl', 'rb') as f:
        choices = pickle.load(f)

    # Convert to tensors
    RTs = tf.constant(RTs, dtype=tf.float32)
    choices = tf.constant(choices, dtype=tf.int32)

    choices_pos = tf.where(choices == 1)[:, 0] # Use tf.where for indexing
    choices_neg = tf.where(choices == -1)[:, 0]

    RTs_pos = tf.gather(RTs, choices_pos)
    RTs_neg = tf.gather(RTs, choices_neg)

    # Use tf.map_fn for parallelization within TensorFlow graph
    prob_pos = tf.map_fn(lambda t: rtd_density_a(t, -v, a, 1-w), RTs_pos)
    prob_neg = tf.map_fn(lambda t: rtd_density_a(t, v, a, w), RTs_neg)

    # Use tf.where for conditional assignment
    prob_pos = tf.where(prob_pos <= 0, 1e-10, prob_pos)
    prob_neg = tf.where(prob_neg <= 0, 1e-10, prob_neg)

    log_pos = tf.math.log(prob_pos)
    log_neg = tf.math.log(prob_neg)

    # Calculate sum of log-likelihoods using TensorFlow operations
    sum_loglike = tf.reduce_sum(log_pos) + tf.reduce_sum(log_neg)
    print('loglike = ', sum_loglike)
    return sum_loglike

# %%
# NUTS init
nuts_kernel = tfp.mcmc.NoUTurnSampler(
    loglike_fn,
    step_size=0.1
)

num_burnin_steps = 100
nuts_adaptive_kernel = tfp.mcmc.DualAveragingStepSizeAdaptation(
    nuts_kernel,
    num_adaptation_steps=int(num_burnin_steps * 0.8),
)

# %%
import random
init_state = [tf.constant(random.uniform(-2,2), dtype=tf.float32),
              tf.constant(random.uniform(1,3), dtype=tf.float32),
              tf.constant(random.uniform(0.3,0.7), dtype=tf.float32)
              ]
chain_output = tfp.mcmc.sample_chain(
    num_results=int(1000),
    num_burnin_steps=num_burnin_steps,
    current_state=init_state,
    kernel=nuts_adaptive_kernel,
    trace_fn=None
)
# Out:
# v,a,w: -1.9101628065109253, 2.1853652000427246, 0.6948953866958618
# v,a,w: -1.9101628065109253, 2.1853652000427246, 0.6948953866958618
# v,a,w: -1.0344585180282593, 1.9167035818099976, 1.8164860010147095
# v,a,w: -1.0344585180282593, 1.9167035818099976, 1.8164860010147095
# v,a,w: 3.5441203117370605, 1.893951416015625, 7.606597900390625
# v,a,w: 3.5441203117370605, 1.893951416015625, 7.606597900390625
# v,a,w: -1.828924536705017, 2.1984059810638428, 0.7890074253082275
# v,a,w: -1.828924536705017, 2.1984059810638428, 0.7890074253082275
# v,a,w: -1.623062252998352, 2.215043067932129, 0.8705007433891296
# v,a,w: -1.623062252998352, 2.215043067932129, 0.8705007433891296
# v,a,w: -1.3252769708633423, 2.237460136413574, 0.6095386743545532
# v,a,w: -1.3252769708633423, 2.237460136413574, 0.6095386743545532
# v,a,w: -1.8423724174499512, 2.165041446685791, 0.7843500971794128
# v,a,w: -1.8423724174499512, 2.165041446685791, 0.7843500971794128
# v,a,w: -1.6475584506988525, 2.1515729427337646, 0.8711338043212891
# v,a,w: -1.6475584506988525, 2.1515729427337646, 0.8711338043212891
# v,a,w: -1.3576527833938599, 2.1517021656036377, 0.6118669509887695
# v,a,w: -1.3576527833938599, 2.1517021656036377, 0.6118669509887695
# v,a,w: -0.9494415521621704, 2.1340177059173584, 0.5471141338348389
# v,a,w: -0.9494415521621704, 2.1340177059173584, 0.5471141338348389
# v,a,w: -1.8366143703460693, 2.204576253890991, 0.7936971783638
# v,a,w: -1.8366143703460693, 2.204576253890991, 0.7936971783638
# v,a,w: -1.8170620203018188, 2.1923561096191406, 0.7838951945304871
# v,a,w: -1.8170620203018188, 2.1923561096191406, 0.7838951945304871
# v,a,w: -1.8010255098342896, 2.1864240169525146, 0.7786790132522583
# v,a,w: -1.8010255098342896, 2.1864240169525146, 0.7786790132522583
# v,a,w: -1.8401421308517456, 2.2108659744262695, 0.797641396522522
# v,a,w: -1.8401421308517456, 2.2108659744262695, 0.797641396522522
# v,a,w: -1.8395254611968994, 2.217268943786621, 0.8005435466766357
# v,a,w: -1.8395254611968994, 2.217268943786621, 0.8005435466766357
# v,a,w: -1.834787368774414, 2.2237730026245117, 0.8021649718284607
# v,a,w: -1.834787368774414, 2.2237730026245117, 0.8021649718284607
# v,a,w: -1.8259541988372803, 2.2303590774536133, 0.8023523688316345
# v,a,w: -1.8259541988372803, 2.2303590774536133, 0.8023523688316345
# v,a,w: 0.17406755685806274, 1.9939806461334229, 0.5080268383026123
# v,a,w: 0.11067552864551544, 2.038012981414795, 0.5413878560066223
# v,a,w: 0.11067552864551544, 2.038012981414795, 0.5413878560066223
# v,a,w: 0.10848663747310638, 2.0412604808807373, 0.528328537940979
# v,a,w: 0.10848663747310638, 2.0412604808807373, 0.528328537940979
# v,a,w: 0.10936883836984634, 2.0428173542022705, 0.5215803980827332
# v,a,w: 0.10936883836984634, 2.0428173542022705, 0.5215803980827332
# v,a,w: 0.11365313827991486, 2.042468309402466, 0.5234158635139465
# v,a,w: 0.11365313827991486, 2.042468309402466, 0.5234158635139465
# v,a,w: 0.12563712894916534, 1.9963206052780151, 0.5044589042663574
# v,a,w: 0.12563712894916534, 1.9963206052780151, 0.5044589042663574
# v,a,w: 0.12639714777469635, 1.9800808429718018, 0.5173963308334351
# v,a,w: 0.12639714777469635, 1.9800808429718018, 0.5173963308334351
# v,a,w: 0.14142216742038727, 1.9671272039413452, 0.5667309761047363
# v,a,w: 0.14142216742038727, 1.9671272039413452, 0.5667309761047363
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 6
#       1 import random
#       2 init_state = [tf.constant(random.uniform(-2,2), dtype=tf.float32),
#       3               tf.constant(random.uniform(1,3), dtype=tf.float32),
#       4               tf.constant(random.uniform(0.3,0.7), dtype=tf.float32)
#       5               ]
# ----> 6 chain_output = tfp.mcmc.sample_chain(
#       7     num_results=int(1000),
#       8     num_burnin_steps=num_burnin_steps,
#       9     current_state=init_state,
#      10     kernel=nuts_adaptive_kernel,
#      11     trace_fn=None
#      12 )
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow_probability/python/mcmc/sample.py:359, in sample_chain(num_results, current_state, previous_kernel_results, kernel, num_burnin_steps, num_steps_between_results, trace_fn, return_final_kernel_results, parallel_iterations, seed, name)
#     352   seed, next_state, current_kernel_results = loop_util.smart_for_loop(
#     353       loop_num_iter=num_steps,
#     354       body_fn=_seeded_one_step,
#     355       initial_loop_vars=list(seed_state_and_results),
#     356       parallel_iterations=parallel_iterations)
#     357   return seed, next_state, current_kernel_results
# --> 359 (_, _, final_kernel_results), (all_states, trace) = loop_util.trace_scan(
#     360     loop_fn=_trace_scan_fn,
#     361     initial_state=(seed, current_state, previous_kernel_results),
#     362     elems=tf.one_hot(
#     363         indices=0,
#     364         depth=num_results,
#     365         on_value=1 + num_burnin_steps,
#     366         off_value=1 + num_steps_between_results,
#     367         dtype=tf.int32),
#     368     # pylint: disable=g-long-lambda
#     369     trace_fn=lambda seed_state_and_results: (
#     370         seed_state_and_results[1], trace_fn(*seed_state_and_results[1:])),
#     371     # pylint: enable=g-long-lambda
#     372     parallel_iterations=parallel_iterations)
#     374 if return_final_kernel_results:
#     375   return CheckpointableStatesAndTrace(
#     376       all_states=all_states,
#     377       trace=trace,
#     378       final_kernel_results=final_kernel_results)
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow_probability/python/internal/loop_util.py:232, in trace_scan(loop_fn, initial_state, elems, trace_fn, trace_criterion_fn, static_trace_allocation_size, condition_fn, parallel_iterations, name)
#     224   trace_arrays, num_steps_traced = ps.cond(
#     225       trace_criterion_fn(state) if trace_criterion_fn else True,
#     226       lambda: (trace_one_step(num_steps_traced, trace_arrays, state),  # pylint: disable=g-long-lambda
#     227                num_steps_traced + 1),
#     228       lambda: (trace_arrays, num_steps_traced))
#     230   return i + 1, state, num_steps_traced, trace_arrays
# --> 232 _, final_state, _, trace_arrays = tf.while_loop(
#     233     cond=condition_fn if condition_fn is not None else lambda *_: True,
#     234     body=_body,
#     235     loop_vars=(0, initial_state, 0, trace_arrays),
#     236     maximum_iterations=length,
#     237     parallel_iterations=parallel_iterations)
#     239 # unflatten
#     240 stacked_trace = tf.nest.pack_sequence_as(
#     241     initial_trace, [ta.stack() for ta in trace_arrays],
#     242     expand_composites=True)
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py:660, in deprecated_arg_values.<locals>.deprecated_wrapper.<locals>.new_func(*args, **kwargs)
#     652           _PRINTED_WARNING[(func, arg_name)] = True
#     653         _log_deprecation(
#     654             'From %s: calling %s (from %s) with %s=%s is deprecated and '
#     655             'will be removed %s.\nInstructions for updating:\n%s',
#    (...)
#     658             'in a future version' if date is None else
#     659             ('after %s' % date), instructions)
# --> 660 return func(*args, **kwargs)
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/ops/while_loop.py:241, in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#      35 @tf_export("while_loop", v1=[])
#      36 @deprecation.deprecated_arg_values(
#      37     None,
#    (...)
#      52                   maximum_iterations=None,
#      53                   name=None):
#      54   """Repeat `body` while the condition `cond` is true.
#      55
#      56   Note: This op is automatically used in a `tf.function` to convert Python for-
#    (...)
#     239
#     240   """
# --> 241   return while_loop(
#     242       cond=cond,
#     243       body=body,
#     244       loop_vars=loop_vars,
#     245       shape_invariants=shape_invariants,
#     246       parallel_iterations=parallel_iterations,
#     247       back_prop=back_prop,
#     248       swap_memory=swap_memory,
#     249       name=name,
#     250       maximum_iterations=maximum_iterations,
#     251       return_same_structure=True)
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/ops/while_loop.py:488, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#     485 loop_var_structure = nest.map_structure(type_spec.type_spec_from_value,
#     486                                         list(loop_vars))
#     487 while cond(*loop_vars):
# --> 488   loop_vars = body(*loop_vars)
#     489   if try_to_pack and not isinstance(loop_vars, (list, tuple)):
#     490     packed = True
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/ops/while_loop.py:479, in while_loop.<locals>.<lambda>(i, lv)
#     476     loop_vars = (counter, loop_vars)
#     477     cond = lambda i, lv: (  # pylint: disable=g-long-lambda
#     478         math_ops.logical_and(i < maximum_iterations, orig_cond(*lv)))
# --> 479     body = lambda i, lv: (i + 1, orig_body(*lv))
#     480   try_to_pack = False
#     482 if executing_eagerly:
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow_probability/python/internal/loop_util.py:222, in trace_scan.<locals>._body(i, state, num_steps_traced, trace_arrays)
#     220 def _body(i, state, num_steps_traced, trace_arrays):
#     221   elem = elems_array.read(i)
# --> 222   state = loop_fn(state, elem)
#     224   trace_arrays, num_steps_traced = ps.cond(
#     225       trace_criterion_fn(state) if trace_criterion_fn else True,
#     226       lambda: (trace_one_step(num_steps_traced, trace_arrays, state),  # pylint: disable=g-long-lambda
#     227                num_steps_traced + 1),
#     228       lambda: (trace_arrays, num_steps_traced))
#     230   return i + 1, state, num_steps_traced, trace_arrays
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow_probability/python/mcmc/sample.py:352, in sample_chain.<locals>._trace_scan_fn(seed_state_and_results, num_steps)
#     351 def _trace_scan_fn(seed_state_and_results, num_steps):
# --> 352   seed, next_state, current_kernel_results = loop_util.smart_for_loop(
#     353       loop_num_iter=num_steps,
#     354       body_fn=_seeded_one_step,
#     355       initial_loop_vars=list(seed_state_and_results),
#     356       parallel_iterations=parallel_iterations)
#     357   return seed, next_state, current_kernel_results
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow_probability/python/internal/loop_util.py:111, in smart_for_loop(loop_num_iter, body_fn, initial_loop_vars, parallel_iterations, unroll_threshold, name)
#     101 if (loop_num_iter_ is None
#     102     or tf.executing_eagerly()
#     103     # large values for loop_num_iter_ will cause ridiculously slow
#    (...)
#     108   # Cast to int32 to run the comparison against i in host memory,
#     109   # where while/LoopCond needs it.
#     110   loop_num_iter = tf.cast(loop_num_iter, dtype=tf.int32)
# --> 111   return tf.while_loop(
#     112       cond=lambda i, *args: i < loop_num_iter,
#     113       body=lambda i, *args: [i + 1] + list(body_fn(*args)),
#     114       loop_vars=[np.int32(0)] + initial_loop_vars,
#     115       parallel_iterations=parallel_iterations
#     116   )[1:]
#     117 result = initial_loop_vars
#     118 for _ in range(loop_num_iter_):
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py:660, in deprecated_arg_values.<locals>.deprecated_wrapper.<locals>.new_func(*args, **kwargs)
#     652           _PRINTED_WARNING[(func, arg_name)] = True
#     653         _log_deprecation(
#     654             'From %s: calling %s (from %s) with %s=%s is deprecated and '
#     655             'will be removed %s.\nInstructions for updating:\n%s',
#    (...)
#     658             'in a future version' if date is None else
#     659             ('after %s' % date), instructions)
# --> 660 return func(*args, **kwargs)
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/ops/while_loop.py:241, in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#      35 @tf_export("while_loop", v1=[])
#      36 @deprecation.deprecated_arg_values(
#      37     None,
#    (...)
#      52                   maximum_iterations=None,
#      53                   name=None):
#      54   """Repeat `body` while the condition `cond` is true.
#      55
#      56   Note: This op is automatically used in a `tf.function` to convert Python for-
#    (...)
#     239
#     240   """
# --> 241   return while_loop(
#     242       cond=cond,
#     243       body=body,
#     244       loop_vars=loop_vars,
#     245       shape_invariants=shape_invariants,
#     246       parallel_iterations=parallel_iterations,
#     247       back_prop=back_prop,
#     248       swap_memory=swap_memory,
#     249       name=name,
#     250       maximum_iterations=maximum_iterations,
#     251       return_same_structure=True)
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/ops/while_loop.py:488, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#     485 loop_var_structure = nest.map_structure(type_spec.type_spec_from_value,
#     486                                         list(loop_vars))
#     487 while cond(*loop_vars):
# --> 488   loop_vars = body(*loop_vars)
#     489   if try_to_pack and not isinstance(loop_vars, (list, tuple)):
#     490     packed = True
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow_probability/python/internal/loop_util.py:113, in smart_for_loop.<locals>.<lambda>(i, *args)
#     101 if (loop_num_iter_ is None
#     102     or tf.executing_eagerly()
#     103     # large values for loop_num_iter_ will cause ridiculously slow
#    (...)
#     108   # Cast to int32 to run the comparison against i in host memory,
#     109   # where while/LoopCond needs it.
#     110   loop_num_iter = tf.cast(loop_num_iter, dtype=tf.int32)
#     111   return tf.while_loop(
#     112       cond=lambda i, *args: i < loop_num_iter,
# --> 113       body=lambda i, *args: [i + 1] + list(body_fn(*args)),
#     114       loop_vars=[np.int32(0)] + initial_loop_vars,
#     115       parallel_iterations=parallel_iterations
#     116   )[1:]
#     117 result = initial_loop_vars
#     118 for _ in range(loop_num_iter_):
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow_probability/python/mcmc/sample.py:349, in sample_chain.<locals>._seeded_one_step(seed, *state_and_results)
# ...
#     739       target_grad_parts=initial_state.target_grad_parts,
#     740       energy=initial_state.target,
#     741       weight=init_weight)
#     742   energy_diff_sum = tf.zeros_like(current_step_meta_info.init_energy,
#     743                                   name='energy_diff_sum')
#     744   [
#     745       _,
#     746       _,
#     747       energy_diff_tree_sum,
#     748       momentum_tree_cumsum,
#     749       leapfrogs_taken,
#     750       final_state,
#     751       candidate_tree_state,
#     752       final_continue_tree,
#     753       final_not_divergence,
#     754       momentum_state_memory,
#     755   ] = tf.while_loop(
#     756       cond=lambda iter_, seed, energy_diff_sum, init_momentum_cumsum,  # pylint: disable=g-long-lambda
#     757                   leapfrogs_taken, state, state_c, continue_tree,
#     758                   not_divergence, momentum_state_memory: (
#     759                       (iter_ < nsteps) & tf.reduce_any(continue_tree)),
#     760       body=lambda iter_, seed, energy_diff_sum, init_momentum_cumsum,  # pylint: disable=g-long-lambda
#     761                   leapfrogs_taken, state, state_c, continue_tree,
#     762                   not_divergence, momentum_state_memory: (
# --> 763                       self._loop_build_sub_tree(
#     764                           directions, integrator, current_step_meta_info,
#     765                           iter_, energy_diff_sum, init_momentum_cumsum,
#     766                           leapfrogs_taken, state, state_c, continue_tree,
#     767                           not_divergence, momentum_state_memory, seed)),
#     768       loop_vars=(
#     769           tf.zeros([], dtype=tf.int32, name='iter'),
#     770           seed,
#     771           energy_diff_sum,
#     772           init_momentum_cumsum,
#     773           tf.zeros(batch_shape, dtype=TREE_COUNT_DTYPE),
#     774           initial_state,
#     775           initial_state_candidate,
#     776           continue_tree,
#     777           not_divergence,
#     778           momentum_state_memory,
#     779       ),
#     780       parallel_iterations=self.parallel_iterations
#     781   )
#     783 return (
#     784     candidate_tree_state,
#     785     final_state,
#    (...)
#     790     leapfrogs_taken,
#     791 )
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow_probability/python/mcmc/nuts.py:816, in NoUTurnSampler._loop_build_sub_tree(self, directions, integrator, current_step_meta_info, iter_, energy_diff_sum_previous, momentum_cumsum_previous, leapfrogs_taken, prev_tree_state, candidate_tree_state, continue_tree_previous, not_divergent_previous, momentum_state_memory, seed)
#     808 acceptance_seed, next_seed = samplers.split_seed(seed)
#     809 with tf.name_scope('loop_build_sub_tree'):
#     810   # Take one leapfrog step in the direction v and check divergence
#     811   [
#     812       next_momentum_parts,
#     813       next_state_parts,
#     814       next_target,
#     815       next_target_grad_parts
# --> 816   ] = integrator(prev_tree_state.momentum,
#     817                  prev_tree_state.state,
#     818                  prev_tree_state.target,
#     819                  prev_tree_state.target_grad_parts)
#     821   next_tree_state = TreeDoublingState(
#     822       momentum=next_momentum_parts,
#     823       state=next_state_parts,
#     824       target=next_target,
#     825       target_grad_parts=next_target_grad_parts)
#     826   momentum_cumsum = [p0 + p1 for p0, p1 in zip(momentum_cumsum_previous,
#     827                                                next_momentum_parts)]
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow_probability/python/mcmc/internal/leapfrog_integrator.py:291, in SimpleLeapfrogIntegrator.__call__(self, momentum_parts, state_parts, target, target_grad_parts, kinetic_energy_fn, name)
#     277 # See Algorithm 1 of "Faster Hamiltonian Monte Carlo by Learning Leapfrog
#     278 # Scale", https://arxiv.org/abs/1810.04449.
#     280 half_next_momentum_parts = [
#     281     v + _multiply(0.5 * eps, g, dtype=v.dtype)
#     282     for v, eps, g
#     283     in zip(momentum_parts, self.step_sizes, target_grad_parts)]
#     285 [
#     286     _,
#     287     next_half_next_momentum_parts,
#     288     next_state_parts,
#     289     next_target,
#     290     next_target_grad_parts,
# --> 291 ] = tf.while_loop(
#     292     cond=lambda i, *_: i < self.num_steps,
#     293     body=lambda i, *args: [i + 1] + list(_one_step(  # pylint: disable=no-value-for-parameter,g-long-lambda
#     294         self.target_fn, self.step_sizes, get_velocity_parts, *args)),
#     295     loop_vars=[
#     296         tf.zeros_like(self.num_steps, name='iter'),
#     297         half_next_momentum_parts,
#     298         state_parts,
#     299         target,
#     300         target_grad_parts,
#     301     ])
#     303 next_momentum_parts = [
#     304     v - _multiply(0.5 * eps, g, dtype=v.dtype)  # pylint: disable=g-complex-comprehension
#     305     for v, eps, g
#    (...)
#     308            next_target_grad_parts)
#     309 ]
#     311 return (
#     312     next_momentum_parts,
#     313     next_state_parts,
#     314     next_target,
#     315     next_target_grad_parts,
#     316 )
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py:660, in deprecated_arg_values.<locals>.deprecated_wrapper.<locals>.new_func(*args, **kwargs)
#     652           _PRINTED_WARNING[(func, arg_name)] = True
#     653         _log_deprecation(
#     654             'From %s: calling %s (from %s) with %s=%s is deprecated and '
#     655             'will be removed %s.\nInstructions for updating:\n%s',
#    (...)
#     658             'in a future version' if date is None else
#     659             ('after %s' % date), instructions)
# --> 660 return func(*args, **kwargs)
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/ops/while_loop.py:241, in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#      35 @tf_export("while_loop", v1=[])
#      36 @deprecation.deprecated_arg_values(
#      37     None,
#    (...)
#      52                   maximum_iterations=None,
#      53                   name=None):
#      54   """Repeat `body` while the condition `cond` is true.
#      55
#      56   Note: This op is automatically used in a `tf.function` to convert Python for-
#    (...)
#     239
#     240   """
# --> 241   return while_loop(
#     242       cond=cond,
#     243       body=body,
#     244       loop_vars=loop_vars,
#     245       shape_invariants=shape_invariants,
#     246       parallel_iterations=parallel_iterations,
#     247       back_prop=back_prop,
#     248       swap_memory=swap_memory,
#     249       name=name,
#     250       maximum_iterations=maximum_iterations,
#     251       return_same_structure=True)
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/ops/while_loop.py:488, in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#     485 loop_var_structure = nest.map_structure(type_spec.type_spec_from_value,
#     486                                         list(loop_vars))
#     487 while cond(*loop_vars):
# --> 488   loop_vars = body(*loop_vars)
#     489   if try_to_pack and not isinstance(loop_vars, (list, tuple)):
#     490     packed = True
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow_probability/python/mcmc/internal/leapfrog_integrator.py:293, in SimpleLeapfrogIntegrator.__call__.<locals>.<lambda>(i, *args)
#     277 # See Algorithm 1 of "Faster Hamiltonian Monte Carlo by Learning Leapfrog
#     278 # Scale", https://arxiv.org/abs/1810.04449.
#     280 half_next_momentum_parts = [
#     281     v + _multiply(0.5 * eps, g, dtype=v.dtype)
#     282     for v, eps, g
#     283     in zip(momentum_parts, self.step_sizes, target_grad_parts)]
#     285 [
#     286     _,
#     287     next_half_next_momentum_parts,
#     288     next_state_parts,
#     289     next_target,
#     290     next_target_grad_parts,
#     291 ] = tf.while_loop(
#     292     cond=lambda i, *_: i < self.num_steps,
# --> 293     body=lambda i, *args: [i + 1] + list(_one_step(  # pylint: disable=no-value-for-parameter,g-long-lambda
#     294         self.target_fn, self.step_sizes, get_velocity_parts, *args)),
#     295     loop_vars=[
#     296         tf.zeros_like(self.num_steps, name='iter'),
#     297         half_next_momentum_parts,
#     298         state_parts,
#     299         target,
#     300         target_grad_parts,
#     301     ])
#     303 next_momentum_parts = [
#     304     v - _multiply(0.5 * eps, g, dtype=v.dtype)  # pylint: disable=g-complex-comprehension
#     305     for v, eps, g
#    (...)
#     308            next_target_grad_parts)
#     309 ]
#     311 return (
#     312     next_momentum_parts,
#     313     next_state_parts,
#     314     next_target,
#     315     next_target_grad_parts,
#     316 )
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow_probability/python/mcmc/internal/leapfrog_integrator.py:336, in _one_step(target_fn, step_sizes, get_velocity_parts, half_next_momentum_parts, state_parts, target, target_grad_parts)
#     332 for state_part, eps, velocity_part in zip(
#     333     state_parts, step_sizes, velocity_parts):
#     334   next_state_parts.append(
#     335       state_part + _multiply(eps, velocity_part, dtype=state_part.dtype))
# --> 336 [next_target, next_target_grad_parts] = mcmc_util.maybe_call_fn_and_grads(
#     337     target_fn, next_state_parts)
#     338 if any(g is None for g in next_target_grad_parts):
#     339   raise ValueError(
#     340       'Encountered `None` gradient.\n'
#     341       '  state_parts: {}\n'
#    (...)
#     345           next_state_parts,
#     346           next_target_grad_parts))
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow_probability/python/mcmc/internal/util.py:297, in maybe_call_fn_and_grads(fn, fn_arg_list, result, grads, check_non_none_grads, name)
#     294 with tf.name_scope(name or 'maybe_call_fn_and_grads'):
#     295   fn_arg_list = (list(fn_arg_list) if is_list_like(fn_arg_list)
#     296                  else [fn_arg_list])
# --> 297   result, grads = _value_and_gradients(fn, fn_arg_list, result, grads)
#     298   if not all(dtype_util.is_floating(r.dtype)
#     299              for r in (result if is_list_like(result) else [result])):  # pylint: disable=superfluous-parens
#     300     raise TypeError('Function result must be a `Tensor` with `float` '
#     301                     '`dtype`.')
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow_probability/python/mcmc/internal/util.py:282, in _value_and_gradients(fn, fn_arg_list, result, grads, name)
#     279   grads = _convert_to_tensor(grads, 'fn_grad')
#     280   return result, grads
# --> 282 _, grads = tfp_math_value_and_gradients(fn, fn_arg_list)
#     284 return result, grads
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow_probability/python/math/gradient.py:108, in value_and_gradient(f, output_gradients, use_gradient_tape, auto_unpack_single_arg, has_aux, name, *args, **kwargs)
#      36 """Computes `f(*args, **kwargs)` and its gradients wrt to `args`, `kwargs`.
#      37
#      38 The function `f` is invoked according to one of the following rules:
#    (...)
#     105     are the gradients of `y` with respect to each of `args` and `kwargs`.
#     106 """
#     107 with tf.name_scope(name or 'value_and_gradient'):
# --> 108   return _value_and_grad_impl(
#     109       f,
#     110       _gradient_new if tf.executing_eagerly() or use_gradient_tape else
#     111       _gradient_old,
#     112       *args,
#     113       output_gradients=output_gradients,
#     114       auto_unpack_single_arg=auto_unpack_single_arg,
#     115       expand_tf_modules_as_trainable_vars=False,
#     116       has_aux=has_aux,
#     117       **kwargs)
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow_probability/python/math/gradient.py:378, in _value_and_grad_impl(f, grad_fn, output_gradients, auto_unpack_single_arg, expand_tf_modules_as_trainable_vars, has_aux, *args, **kwargs)
#     374   real_f = f
#     375   f = lambda *args, **kwargs: (real_f(*args, **kwargs)  # pylint: disable=g-long-lambda
#     376                                if _has_args(real_f) else real_f(), ())
# --> 378 y, dydx, aux = grad_fn(lambda: f(*args, **kwargs) if _has_args(f) else f(),
#     379                        tf.nest.flatten([expand_args, expand_kwargs]),
#     380                        output_gradients)
#     381 dydx_args, dydx_kwargs = tf.nest.pack_sequence_as(
#     382     [expand_args, expand_kwargs], dydx)
#     383 if len(args) == 1 and not do_unpack:
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow_probability/python/math/gradient.py:325, in _gradient_new(f, xs, grad_ys)
#     323     tape.watch(x)
#     324   y, aux = f()
# --> 325 return y, tape.gradient(y, xs, output_gradients=grad_ys), aux
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/eager/backprop.py:1066, in GradientTape.gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1060   output_gradients = (
#    1061       composite_tensor_gradient.get_flat_tensors_for_gradients(
#    1062           output_gradients))
#    1063   output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1064                       for x in output_gradients]
# -> 1066 flat_grad = imperative_grad.imperative_grad(
#    1067     self._tape,
#    1068     flat_targets,
#    1069     flat_sources,
#    1070     output_gradients=output_gradients,
#    1071     sources_raw=flat_sources_raw,
#    1072     unconnected_gradients=unconnected_gradients)
#    1074 if not self._persistent:
#    1075   # Keep track of watched variables before setting tape to None
#    1076   self._watched_variables = self._tape.watched_variables()
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/eager/imperative_grad.py:67, in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63 except ValueError:
#      64   raise ValueError(
#      65       "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
# ---> 67 return pywrap_tfe.TFE_Py_TapeGradient(
#      68     tape._tape,  # pylint: disable=protected-access
#      69     target,
#      70     sources,
#      71     output_gradients,
#      72     sources_raw,
#      73     compat.as_str(unconnected_gradients.value))
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/eager/backprop.py:148, in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     146     gradient_name_scope += forward_pass_name_scope + "/"
#     147   with ops.name_scope(gradient_name_scope):
# --> 148     return grad_fn(mock_op, *out_grads)
#     149 else:
#     150   return grad_fn(mock_op, *out_grads)
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/ops/math_grad.py:1653, in _SelectGradV2(op, grad)
#    1651 y = op.inputs[2]
#    1652 z = op.outputs[0]
# -> 1653 zeros = array_ops.zeros([], dtype=grad.dtype.base_dtype)
#    1654 gx = array_ops.where_v2(c, grad, zeros)
#    1655 gy = array_ops.where_v2(c, zeros, grad)
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1254, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1252 if iterable_params is not None:
#    1253   args, kwargs = replace_iterable_params(args, kwargs, iterable_params)
# -> 1254 result = api_dispatcher.Dispatch(args, kwargs)
#    1255 if result is not NotImplemented:
#    1256   return result
#
# KeyboardInterrupt:
