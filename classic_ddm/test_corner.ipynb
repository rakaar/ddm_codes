# %%
from dynesty import NestedSampler
from dynesty import plotting as dyplot
from ddm_utils import simulate_ddm, parse_sim_results
from joblib import Parallel, delayed
import pickle
from dynesty_utiils import loglike_fn, prior_transform, _quantile

import matplotlib.pyplot as plt
import numpy as np
from ex23_utils import run_vbmc, save_prior_bounds
import multiprocessing
import os
import pymc as pm
import corner
from nuts_pymc_utils import loglike_fn_NUTS

num_processes = multiprocessing.cpu_count()

# save dynesty bounds
priors_bounds = { 
    'v': [-5,5],
    'a': [1, 3],
    'w': [0.3, 0.7] 
}
with open('dynesty_priors.pkl', 'wb') as f:
    pickle.dump(priors_bounds, f)

# save VBMC bounds
prior_bounds = { 'v_low': -5, 'v_high': 5, 'a_low': 1, 'a_high': 3, 'w_low': 0.3, 'w_high': 0.7 }
save_prior_bounds(prior_bounds)

# search bounds for VBMC
lb = np.array([-5, 1, 0.3]); ub = np.array([5, 3, 0.7])
plb = np.array([-4.9,1.1,0.31]); pub = np.array([4.9,2.9,0.69])

# data sim
# N_trials_arr = [100, 500, 1000, 5000]
N_trials_arr = [100]


corner_span = [(-0.2, 0.75), (1.6, 2.4), (0.4, 0.6)]
param_labels = ['v', 'a', 'w']
true_v = 0.2; true_a = 2; true_w = 0.5
true_arr = [true_v, true_a, true_w]

save_path = "/home/rka/Pictures/test" 

N_sim = 100
# for N_sim in N_trials_arr:
print(f'################################ processing {N_sim} ################################')

# save data
sim_results = Parallel(n_jobs=-1)(delayed(simulate_ddm)(true_v, true_a) for _ in range(N_sim))
choices, RTs = parse_sim_results(sim_results)
with open('sample_rt.pkl', 'wb') as f:
    pickle.dump(RTs, f)
with open('sample_choice.pkl', 'wb') as f:
    pickle.dump(choices, f)
data_dict = {'choices': choices, 'RTs': RTs}

# Nested sampling
pool = multiprocessing.Pool(processes=num_processes)
ndim = 3
sampler = NestedSampler(loglike_fn, prior_transform, ndim, pool=pool, queue_size=num_processes)
sampler.run_nested()
pool.close()
pool.join()
nested_samp_results = sampler.results

# NS Corner plots
title_kwargs = {'fontsize': 10}  # Increase the title font size
label_kwargs = {'fontsize': 10}  # Increase the label font size
tick_labelsize = 12

fig, axes = dyplot.cornerplot(nested_samp_results, color='blue', truths=np.array(true_arr),
                              truth_color='black', show_titles=True,
                              max_n_ticks=5, labels=param_labels,
                              label_kwargs=label_kwargs,
                              title_kwargs=title_kwargs, span=corner_span)

# Adjust tick parameters
for ax in axes.reshape(-1):  # Flatten the axes array and iterate through each subplot
    ax.tick_params(axis='both', which='major', labelsize=tick_labelsize)

filename_ns = f"TEMP_corner_nested_sample_{N_sim}.png"
fig.savefig(filename_ns)
plt.close(fig)


    # VBMC
# x0 = np.array([np.random.uniform(plb[0], pub[0]), np.random.uniform(plb[1], pub[1]), np.random.uniform(plb[2], pub[2])])
# vp, results = run_vbmc(x0, lb, ub, plb, pub)

# v_a_w, _ = vp.sample(int(1e5))
# v_samp = v_a_w[:,0]; a_samp = v_a_w[:,1]; w_samp = v_a_w[:,2]
# combined_samples = np.transpose(np.vstack((v_samp, a_samp, w_samp)))
# figure = corner.corner(combined_samples, labels=param_labels, show_titles=True, quantiles=[0.025, 0.5, 0.975],range=corner_span, truths=true_arr)
# # filename = f"corner_vbmc_{N_sim}.png"  # You can change the filename as needed
# # plt.savefig(os.path.join(save_path, filename))
# plt.close(figure)  # Close the figure to free 
# plt.show()
# Out:
# ################################ processing 100 ################################
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# 1781it [00:16, 34.67it/s, bound: 0 | nc: 60 | ncall: 17836 | eff(%):  9.985 | loglstar:   -inf < -170.465 <    inf | logz: -176.380 +/-  0.099 | dlogz: 20.118 >  0.509] /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# 1785it [00:17, 31.38it/s, bound: 1 | nc: 1 | ncall: 17847 | eff(%): 10.002 | loglstar:   -inf < -170.321 <    inf | logz: -176.294 +/-  0.099 | dlogz: 20.024 >  0.509] /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# 2170it [00:17, 411.66it/s, bound: 1 | nc: 2 | ncall: 18528 | eff(%): 11.712 | loglstar:   -inf < -163.030 <    inf | logz: -169.434 +/-  0.103 | dlogz: 12.517 >  0.509]/home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# 2532it [00:18, 407.75it/s, bound: 2 | nc: 2 | ncall: 19294 | eff(%): 13.123 | loglstar:   -inf < -159.105 <    inf | logz: -165.543 +/-  0.104 | dlogz:  7.895 >  0.509]/home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# 2936it [00:19, 416.36it/s, bound: 3 | nc: 1 | ncall: 20076 | eff(%): 14.624 | loglstar:   -inf < -156.191 <    inf | logz: -163.014 +/-  0.106 | dlogz:  4.607 >  0.509]/home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# 3321it [00:20, 409.78it/s, bound: 4 | nc: 1 | ncall: 20757 | eff(%): 15.999 | loglstar:   -inf < -154.721 <    inf | logz: -161.632 +/-  0.107 | dlogz:  2.532 >  0.509]/home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# 3721it [00:21, 422.55it/s, bound: 5 | nc: 1 | ncall: 21499 | eff(%): 17.308 | loglstar:   -inf < -153.765 <    inf | logz: -160.853 +/-  0.109 | dlogz:  1.262 >  0.509]/home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# 3767it [00:22, 292.75it/s, bound: 6 | nc: 1 | ncall: 21607 | eff(%): 17.434 | loglstar:   -inf < -153.681 <    inf | logz: -160.790 +/-  0.109 | dlogz:  1.154 >  0.509]/home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# 4122it [00:22, 449.83it/s, bound: 6 | nc: 1 | ncall: 22245 | eff(%): 18.530 | loglstar:   -inf < -153.192 <    inf | logz: -160.435 +/-  0.109 | dlogz:  0.559 >  0.509]/home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# 4166it [00:23, 181.11it/s, +500 | bound: 7 | nc: 1 | ncall: 22868 | eff(%): 20.860 | loglstar:   -inf < -152.492 <    inf | logz: -160.029 +/-  0.118 | dlogz:  0.001 >  0.509]

# %%
    # VBMC
x0 = np.array([np.random.uniform(plb[0], pub[0]), np.random.uniform(plb[1], pub[1]), np.random.uniform(plb[2], pub[2])])
vp, results = run_vbmc(x0, lb, ub, plb, pub)

v_a_w, _ = vp.sample(int(1e5))
v_samp = v_a_w[:,0]; a_samp = v_a_w[:,1]; w_samp = v_a_w[:,2]
combined_samples = np.transpose(np.vstack((v_samp, a_samp, w_samp)))
figure = corner.corner(combined_samples, labels=param_labels, show_titles=True, quantiles=[0.025, 0.5, 0.975],range=corner_span, truths=true_arr)
# filename = f"corner_vbmc_{N_sim}.png"  # You can change the filename as needed
# plt.savefig(os.path.join(save_path, filename))
# plt.close(figure)  # Close the figure to free 
plt.show()
# Out:
# Reshaping x0 to row vector.
# Reshaping lower bounds to (1, 3).
# Reshaping upper bounds to (1, 3).
# Reshaping plausible lower bounds to (1, 3).
# Reshaping plausible upper bounds to (1, 3).
# Inference terminated: variational solution stable for options.tol_stable_count fcn evaluations.
# Estimated ELBO: -162.869 +/-0.001.

# %%
figure = corner.corner(combined_samples, labels=param_labels, show_titles=True, quantiles=[0.025, 0.5, 0.975],range=corner_span, truths=true_arr)
# filename = f"corner_vbmc_{N_sim}.png"  # You can change the filename as needed
# plt.savefig(os.path.join(save_path, filename))
# plt.close(figure)  # Close the figure to free 
# plt.show()
figure.savefig(f"TEMP_corner_vbmc_{N_sim}.png")

# %% [markdown]
# # Don't save show

# %%
from dynesty import NestedSampler
from dynesty import plotting as dyplot
from ddm_utils import simulate_ddm, parse_sim_results
from joblib import Parallel, delayed
import pickle
from dynesty_utiils import loglike_fn, prior_transform, _quantile

import matplotlib.pyplot as plt
import numpy as np
from ex23_utils import run_vbmc, save_prior_bounds
import multiprocessing
import os
import pymc as pm
import corner
from nuts_pymc_utils import loglike_fn_NUTS

num_processes = multiprocessing.cpu_count()

# save dynesty bounds
priors_bounds = { 
    'v': [-5,5],
    'a': [1, 3],
    'w': [0.3, 0.7] 
}
with open('dynesty_priors.pkl', 'wb') as f:
    pickle.dump(priors_bounds, f)

# save VBMC bounds
prior_bounds = { 'v_low': -5, 'v_high': 5, 'a_low': 1, 'a_high': 3, 'w_low': 0.3, 'w_high': 0.7 }
save_prior_bounds(prior_bounds)

# search bounds for VBMC
lb = np.array([-5, 1, 0.3]); ub = np.array([5, 3, 0.7])
plb = np.array([-4.9,1.1,0.31]); pub = np.array([4.9,2.9,0.69])

# data sim
# N_trials_arr = [100, 500, 1000, 5000]
N_trials_arr = [15]


corner_span = [(-0.2, 0.75), (1.6, 2.4), (0.4, 0.6)]
param_labels = ['v', 'a', 'w']
true_v = 0.2; true_a = 2; true_w = 0.5
true_arr = [true_v, true_a, true_w]

save_path = "/home/rka/Pictures" 

for N_sim in N_trials_arr:
    print(f'################################ processing {N_sim} ################################')

    # save data
    sim_results = Parallel(n_jobs=-1)(delayed(simulate_ddm)(true_v, true_a) for _ in range(N_sim))
    choices, RTs = parse_sim_results(sim_results)
    with open('sample_rt.pkl', 'wb') as f:
        pickle.dump(RTs, f)
    with open('sample_choice.pkl', 'wb') as f:
        pickle.dump(choices, f)
    data_dict = {'choices': choices, 'RTs': RTs}

    # Nested sampling
    pool = multiprocessing.Pool(processes=num_processes)
    ndim = 3
    sampler = NestedSampler(loglike_fn, prior_transform, ndim, pool=pool, queue_size=num_processes)
    sampler.run_nested()
    pool.close()
    pool.join()
    nested_samp_results = sampler.results

    # NS Corner plots
    title_kwargs = {'fontsize': 12}  # Increase the title font size
    label_kwargs = {'fontsize': 12}  # Increase the label font size
    tick_labelsize = 14

    fig_1, axes = dyplot.cornerplot(nested_samp_results, color='blue', truths=np.array(true_arr),
                                truth_color='black', show_titles=True,
                                max_n_ticks=5, labels=param_labels,
                                label_kwargs=label_kwargs,
                                title_kwargs=title_kwargs, span=corner_span)

    # Adjust tick parameters
    for ax in axes.reshape(-1):  # Flatten the axes array and iterate through each subplot
        ax.tick_params(axis='both', which='major', labelsize=tick_labelsize)
    filename_ns = f"corner_nested_sample_{N_sim}.png"
    # fig_1.savefig(f"{save_path}/{filename_ns}")
    # plt.close(fig_1)
    # plt.title('Nested Sampling')
    plt.show()

    

    # VBMC
    x0 = np.array([np.random.uniform(plb[0], pub[0]), np.random.uniform(plb[1], pub[1]), np.random.uniform(plb[2], pub[2])])
    vp, results = run_vbmc(x0, lb, ub, plb, pub)

    v_a_w, _ = vp.sample(int(1e5))
    v_samp = v_a_w[:,0]; a_samp = v_a_w[:,1]; w_samp = v_a_w[:,2]
    combined_samples_vb = np.transpose(np.vstack((v_samp, a_samp, w_samp)))
    figure_2 = corner.corner(combined_samples_vb, labels=param_labels, show_titles=True, quantiles=[0.025, 0.5, 0.975],range=corner_span, truths=true_arr)
    filename_vb = f"corner_vbmc_{N_sim}.png"  # You can change the filename as needed
    # figure_2.savefig(f"{save_path}/{filename_vb}")
    # plt.close(figure_2)  # Close the figure to free 
    # plt.title('VBMC')   
    plt.show()

    # NUTS
    with pm.Model() as model:
        v_ = pm.Uniform('v', lower=-5, upper=5)
        a_ = pm.Uniform('a', lower=1, upper=3)
        w_ = pm.Uniform('w', lower=0.3, upper=0.7)

        likelihood = pm.Potential('likelihood', loglike_fn_NUTS(v_,a_,w_, data_dict))

        trace = pm.sample(25000, step = pm.NUTS())
        

    v_samples = trace.posterior['v'].values.flatten()
    a_samples = trace.posterior['a'].values.flatten()
    w_samples = trace.posterior['w'].values.flatten()

    combined_samples_nuts = np.transpose(np.vstack((v_samples, a_samples, w_samples)))



    figure_3 = corner.corner(combined_samples_nuts, labels=param_labels, show_titles=True, quantiles=[0.025, 0.5, 0.975],range=corner_span, truths=true_arr)
    filename_nuts = f"corner_nuts_{N_sim}.png"  # You can change the filename as needed
    # figure_3.savefig(f"{save_path}/{filename_nuts}")
    # plt.close(figure_3)  # Close the figure to free 
    # plt.title('NUTS')
    plt.show()
# Out:
# ################################ processing 15 ################################
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# 1735it [00:10, 43.62it/s, bound: 0 | nc: 9 | ncall: 17262 | eff(%): 10.051 | loglstar:   -inf < -27.876 <    inf | logz: -32.137 +/-  0.080 | dlogz:  3.682 >  0.509]  /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# 1741it [00:10, 35.02it/s, bound: 1 | nc: 2 | ncall: 17437 | eff(%):  9.985 | loglstar:   -inf < -27.844 <    inf | logz: -32.111 +/-  0.080 | dlogz:  3.644 >  0.509]/home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# 2061it [00:11, 425.13it/s, bound: 1 | nc: 5 | ncall: 18127 | eff(%): 11.370 | loglstar:   -inf < -26.703 <    inf | logz: -31.050 +/-  0.081 | dlogz:  2.075 >  0.509]/home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# 2481it [00:12, 569.07it/s, bound: 2 | nc: 1 | ncall: 18930 | eff(%): 13.106 | loglstar:   -inf < -25.943 <    inf | logz: -30.330 +/-  0.081 | dlogz:  0.909 >  0.509]/home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# 2759it [00:12, 215.00it/s, +500 | bound: 3 | nc: 1 | ncall: 19887 | eff(%): 16.810 | loglstar:   -inf < -24.983 <    inf | logz: -29.711 +/-  0.090 | dlogz:  0.001 >  0.509]
# Reshaping x0 to row vector.
# Reshaping lower bounds to (1, 3).
# Reshaping upper bounds to (1, 3).
# Reshaping plausible lower bounds to (1, 3).
# Reshaping plausible upper bounds to (1, 3).
# Inference terminated: variational solution stable for options.tol_stable_count fcn evaluations.
# Estimated ELBO: -29.840 +/-0.001.
# Multiprocess sampling (4 chains in 4 jobs)
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [v, a, w]
# NUTS: [v, a, w]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 1_000 tune and 25_000 draw iterations (4_000 + 100_000 draws total) took 132 seconds.
# Sampling 4 chains for 1_000 tune and 25_000 draw iterations (4_000 + 100_000 draws total) took 132 seconds.

# %%
from dynesty import NestedSampler
from dynesty import plotting as dyplot
from ddm_utils import simulate_ddm, parse_sim_results
from joblib import Parallel, delayed
import pickle
from dynesty_utiils import loglike_fn, prior_transform, _quantile

import matplotlib.pyplot as plt
import numpy as np
from ex23_utils import run_vbmc, save_prior_bounds
import multiprocessing
import os
import pymc as pm
import corner
from nuts_pymc_utils import loglike_fn_NUTS

num_processes = multiprocessing.cpu_count()

# save dynesty bounds
priors_bounds = { 
    'v': [-5,5],
    'a': [1, 3],
    'w': [0.3, 0.7] 
}
with open('dynesty_priors.pkl', 'wb') as f:
    pickle.dump(priors_bounds, f)

# save VBMC bounds
prior_bounds = { 'v_low': -5, 'v_high': 5, 'a_low': 1, 'a_high': 3, 'w_low': 0.3, 'w_high': 0.7 }
save_prior_bounds(prior_bounds)

# search bounds for VBMC
lb = np.array([-5, 1, 0.3]); ub = np.array([5, 3, 0.7])
plb = np.array([-4.9,1.1,0.31]); pub = np.array([4.9,2.9,0.69])

# data sim
# N_trials_arr = [100, 500, 1000, 5000]
N_trials_arr = [15]


corner_span = [(-0.2, 0.75), (1.6, 2.4), (0.4, 0.6)]
param_labels = ['v', 'a', 'w']
true_v = 0.2; true_a = 2; true_w = 0.5
true_arr = [true_v, true_a, true_w]

save_path = "/home/rka/Pictures" 

for N_sim in N_trials_arr:
    print(f'################################ processing {N_sim} ################################')

    # save data
    sim_results = Parallel(n_jobs=-1)(delayed(simulate_ddm)(true_v, true_a) for _ in range(N_sim))
    choices, RTs = parse_sim_results(sim_results)
    with open('sample_rt.pkl', 'wb') as f:
        pickle.dump(RTs, f)
    with open('sample_choice.pkl', 'wb') as f:
        pickle.dump(choices, f)
    data_dict = {'choices': choices, 'RTs': RTs}

    # Nested sampling
    pool = multiprocessing.Pool(processes=num_processes)
    ndim = 3
    sampler = NestedSampler(loglike_fn, prior_transform, ndim, pool=pool, queue_size=num_processes)
    sampler.run_nested()
    pool.close()
    pool.join()
    nested_samp_results = sampler.results

    # NS Corner plots
    title_kwargs = {'fontsize': 12}  # Increase the title font size
    label_kwargs = {'fontsize': 12}  # Increase the label font size
    tick_labelsize = 14

    fig_1, axes = dyplot.cornerplot(nested_samp_results, color='blue', truths=np.array(true_arr),
                                truth_color='black', show_titles=True,
                                max_n_ticks=5, labels=param_labels,
                                label_kwargs=label_kwargs,
                                title_kwargs=title_kwargs, span=corner_span)

    # Adjust tick parameters
    for ax in axes.reshape(-1):  # Flatten the axes array and iterate through each subplot
        ax.tick_params(axis='both', which='major', labelsize=tick_labelsize)
    filename_ns = f"corner_nested_sample_{N_sim}.png"
    # fig_1.savefig(f"{save_path}/{filename_ns}")
    # plt.close(fig_1)
    # plt.title('Nested Sampling')
    plt.show()

    # NUTS
    with pm.Model() as model:
        v_ = pm.Uniform('v', lower=-5, upper=5)
        a_ = pm.Uniform('a', lower=1, upper=3)
        w_ = pm.Uniform('w', lower=0.3, upper=0.7)

        likelihood = pm.Potential('likelihood', loglike_fn_NUTS(v_,a_,w_, data_dict))

        trace = pm.sample(25000, step = pm.NUTS())
        

    v_samples = trace.posterior['v'].values.flatten()
    a_samples = trace.posterior['a'].values.flatten()
    w_samples = trace.posterior['w'].values.flatten()

    combined_samples_nuts = np.transpose(np.vstack((v_samples, a_samples, w_samples)))



    figure_3 = corner.corner(combined_samples_nuts, labels=param_labels, show_titles=True, quantiles=[0.025, 0.5, 0.975],range=corner_span, truths=true_arr)
    filename_nuts = f"corner_nuts_{N_sim}.png"  # You can change the filename as needed
    # figure_3.savefig(f"{save_path}/{filename_nuts}")
    # plt.close(figure_3)  # Close the figure to free 
    # plt.title('NUTS')
    plt.show()
    

    # VBMC
    x0 = np.array([np.random.uniform(plb[0], pub[0]), np.random.uniform(plb[1], pub[1]), np.random.uniform(plb[2], pub[2])])
    vp, results = run_vbmc(x0, lb, ub, plb, pub)

    v_a_w, _ = vp.sample(int(1e5))
    v_samp = v_a_w[:,0]; a_samp = v_a_w[:,1]; w_samp = v_a_w[:,2]
    combined_samples_vb = np.transpose(np.vstack((v_samp, a_samp, w_samp)))
    figure_2 = corner.corner(combined_samples_vb, labels=param_labels, show_titles=True, quantiles=[0.025, 0.5, 0.975],range=corner_span, truths=true_arr)
    filename_vb = f"corner_vbmc_{N_sim}.png"  # You can change the filename as needed
    # figure_2.savefig(f"{save_path}/{filename_vb}")
    # plt.close(figure_2)  # Close the figure to free 
    # plt.title('VBMC')   
    plt.show()
# Out:
# ################################ processing 15 ################################
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# 1748it [00:11, 26.91it/s, bound: 0 | nc: 267 | ncall: 17490 | eff(%):  9.994 | loglstar:   -inf < -28.459 <    inf | logz: -32.636 +/-  0.081 | dlogz:  3.236 >  0.509]/home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# 1752it [00:11, 26.45it/s, bound: 1 | nc: 1 | ncall: 17498 | eff(%): 10.013 | loglstar:   -inf < -28.449 <    inf | logz: -32.621 +/-  0.081 | dlogz:  3.213 >  0.509]  /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# 2124it [00:12, 435.60it/s, bound: 1 | nc: 7 | ncall: 18182 | eff(%): 11.682 | loglstar:   -inf < -27.434 <    inf | logz: -31.609 +/-  0.080 | dlogz:  1.654 >  0.509]/home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# 2500it [00:13, 562.04it/s, bound: 2 | nc: 3 | ncall: 18861 | eff(%): 13.255 | loglstar:   -inf < -26.823 <    inf | logz: -31.097 +/-  0.080 | dlogz:  0.786 >  0.509]/home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# /home/rka/code/ddm_codes/venv/lib/python3.10/site-packages/joblib/parallel.py:1359: UserWarning: Loky-backed parallel loops cannot be called in a multiprocessing, setting n_jobs=1
#   n_jobs = self._backend.configure(n_jobs=self.n_jobs, parallel=self,
# 2709it [00:13, 198.49it/s, +500 | bound: 3 | nc: 1 | ncall: 19752 | eff(%): 16.668 | loglstar:   -inf < -25.927 <    inf | logz: -30.561 +/-  0.089 | dlogz:  0.001 >  0.509]
# Multiprocess sampling (4 chains in 4 jobs)
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [v, a, w]
# NUTS: [v, a, w]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 1_000 tune and 25_000 draw iterations (4_000 + 100_000 draws total) took 126 seconds.
# Sampling 4 chains for 1_000 tune and 25_000 draw iterations (4_000 + 100_000 draws total) took 126 seconds.
# Reshaping x0 to row vector.
# Reshaping lower bounds to (1, 3).
# Reshaping upper bounds to (1, 3).
# Reshaping plausible lower bounds to (1, 3).
# Reshaping plausible upper bounds to (1, 3).
# Inference terminated: variational solution stable for options.tol_stable_count fcn evaluations.
# Estimated ELBO: -30.612 +/-0.002.
