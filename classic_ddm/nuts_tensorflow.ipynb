# %%
# tensor flow
import tensorflow_probability as tfp
import tensorflow as tf

# rest
from numba import njit, jit
import matplotlib.pyplot as plt
import numpy as np
import pickle
from joblib import Parallel, delayed

# parse
from ddm_utils import simulate_ddm, parse_sim_results

# %%
N_sim = 100; v = 0.2; a = 2
sim_results = Parallel(n_jobs=-1)(delayed(simulate_ddm)(v, a) for _ in range(N_sim))


choices, RTs = parse_sim_results(sim_results)
    
with open('sample_rt.pkl', 'wb') as f:
    pickle.dump(RTs, f)
with open('sample_choice.pkl', 'wb') as f:
    pickle.dump(choices, f)

# %%
def rtd_density_a(t, v, a, w, K_max=10):
    # Use tf operations instead of numpy
    if tf.greater(t, 0.25):
        non_sum_term = (np.pi/a**2)*tf.exp(-v*a*w - (v**2 * t/2))
        k_vals = tf.linspace(1., tf.cast(K_max, tf.float32), K_max)
        sum_sine_term = tf.sin(k_vals*np.pi*w)
        sum_exp_term = tf.exp(-(k_vals**2 * np.pi**2 * t)/(2*a**2))
        sum_result = tf.reduce_sum(k_vals * sum_sine_term * sum_exp_term)
    else:
        non_sum_term = (1/a**2)*(a**3/tf.sqrt(2*np.pi*t**3))*tf.exp(-v*a*w - (v**2 * t)/2)
        K_max = int(K_max/2)
        k_vals = tf.linspace(tf.cast(-K_max, tf.float32), tf.cast(K_max, tf.float32), 2*K_max + 1)
        sum_w_term = w + 2*k_vals
        sum_exp_term = tf.exp(-(a**2 * (w + 2*k_vals)**2)/(2*t))
        sum_result = tf.reduce_sum(sum_w_term*sum_exp_term)


    density =  non_sum_term * sum_result
    density = tf.where(density <= 0, 1e-10, density) # Use tf.where for conditional assignment
    return density


def loglike_fn(v,a,w):
    # No need to convert to numpy arrays, keep them as tensors

     # Load RTs and choices from the saved files
    print(f"v,a,w: {v}, {a}, {w}")
    with open('sample_rt.pkl', 'rb') as f:
        RTs = pickle.load(f)
    with open('sample_choice.pkl', 'rb') as f:
        choices = pickle.load(f)

    # Convert to tensors
    RTs = tf.constant(RTs, dtype=tf.float32)
    choices = tf.constant(choices, dtype=tf.int32)

    choices_pos = tf.where(choices == 1)[:, 0] # Use tf.where for indexing
    choices_neg = tf.where(choices == -1)[:, 0]

    RTs_pos = tf.gather(RTs, choices_pos)
    RTs_neg = tf.gather(RTs, choices_neg)

    # Use tf.map_fn for parallelization within TensorFlow graph
    prob_pos = tf.map_fn(lambda t: rtd_density_a(t, -v, a, 1-w), RTs_pos)
    prob_neg = tf.map_fn(lambda t: rtd_density_a(t, v, a, w), RTs_neg)

    # Use tf.where for conditional assignment
    prob_pos = tf.where(prob_pos <= 0, 1e-10, prob_pos)
    prob_neg = tf.where(prob_neg <= 0, 1e-10, prob_neg)

    log_pos = tf.math.log(prob_pos)
    log_neg = tf.math.log(prob_neg)

    # Calculate sum of log-likelihoods using TensorFlow operations
    sum_loglike = tf.reduce_sum(log_pos) + tf.reduce_sum(log_neg)
    print('loglike = ', sum_loglike)
    return sum_loglike

# %%
# NUTS init
nuts_kernel = tfp.mcmc.NoUTurnSampler(
    loglike_fn,
    step_size=0.1
)

num_burnin_steps = 100
nuts_adaptive_kernel = tfp.mcmc.DualAveragingStepSizeAdaptation(
    nuts_kernel,
    num_adaptation_steps=int(num_burnin_steps * 0.8),
)

# %%
import random
init_state = [tf.constant(random.uniform(-2,2), dtype=tf.float32),
              tf.constant(random.uniform(1,3), dtype=tf.float32),
              tf.constant(random.uniform(0.3,0.7), dtype=tf.float32)
              ]
chain_output = tfp.mcmc.sample_chain(
    num_results=int(1000),
    num_burnin_steps=num_burnin_steps,
    current_state=init_state,
    kernel=nuts_adaptive_kernel,
    trace_fn=None
)
# Out:
# v,a,w: -0.07520861178636551, 2.2097630500793457, 0.6328628063201904
# loglike =  tf.Tensor(-161.54095, shape=(), dtype=float32)
# v,a,w: -0.07520861178636551, 2.2097630500793457, 0.6328628063201904
# loglike =  tf.Tensor(-161.54095, shape=(), dtype=float32)
# v,a,w: 0.19510459899902344, 2.158651113510132, 0.2182157039642334
# loglike =  tf.Tensor(-223.37079, shape=(), dtype=float32)
# v,a,w: 0.19510459899902344, 2.158651113510132, 0.2182157039642334
# loglike =  tf.Tensor(-223.37079, shape=(), dtype=float32)
# v,a,w: 1.2428256273269653, 1.4181015491485596, 4.7622528076171875
# loglike =  tf.Tensor(-1041.2998, shape=(), dtype=float32)
# v,a,w: 1.2428256273269653, 1.4181015491485596, 4.7622528076171875
# loglike =  tf.Tensor(-1041.2998, shape=(), dtype=float32)
# v,a,w: 1.024801254272461, 1.803241491317749, -2.2295587062835693
# loglike =  tf.Tensor(-2302.5852, shape=(), dtype=float32)
# v,a,w: 1.024801254272461, 1.803241491317749, -2.2295587062835693
# loglike =  tf.Tensor(-2302.5852, shape=(), dtype=float32)
# v,a,w: -0.04257795587182045, 2.2007575035095215, 0.5626047253608704
# loglike =  tf.Tensor(-158.02824, shape=(), dtype=float32)
# v,a,w: -0.04257795587182045, 2.2007575035095215, 0.5626047253608704
# loglike =  tf.Tensor(-158.02824, shape=(), dtype=float32)
# v,a,w: -0.09439221024513245, 2.204537868499756, 0.6287616491317749
# loglike =  tf.Tensor(-161.44766, shape=(), dtype=float32)
# v,a,w: -0.09439221024513245, 2.204537868499756, 0.6287616491317749
# loglike =  tf.Tensor(-161.44766, shape=(), dtype=float32)
# v,a,w: -0.09772521257400513, 2.185375452041626, 0.5592077374458313
# loglike =  tf.Tensor(-159.49754, shape=(), dtype=float32)
# v,a,w: -0.09772521257400513, 2.185375452041626, 0.5592077374458313
# loglike =  tf.Tensor(-159.49754, shape=(), dtype=float32)
# v,a,w: -0.09981827437877655, 2.16705060005188, 0.6360243558883667
# loglike =  tf.Tensor(-161.6286, shape=(), dtype=float32)
# v,a,w: -0.09981827437877655, 2.16705060005188, 0.6360243558883667
# loglike =  tf.Tensor(-161.6286, shape=(), dtype=float32)
# v,a,w: -0.06509807705879211, 2.221038341522217, 0.5229392051696777
# loglike =  tf.Tensor(-160.95494, shape=(), dtype=float32)
# v,a,w: -0.06509807705879211, 2.221038341522217, 0.5229392051696777
# loglike =  tf.Tensor(-160.95494, shape=(), dtype=float32)
# v,a,w: 0.014411546289920807, 2.2026262283325195, 0.5122252106666565
# loglike =  tf.Tensor(-158.35951, shape=(), dtype=float32)
# v,a,w: 0.014411546289920807, 2.2026262283325195, 0.5122252106666565
# loglike =  tf.Tensor(-158.35951, shape=(), dtype=float32)
# v,a,w: -0.017814859747886658, 2.2256689071655273, 0.5567337870597839
# loglike =  tf.Tensor(-157.97443, shape=(), dtype=float32)
# v,a,w: -0.017814859747886658, 2.2256689071655273, 0.5567337870597839
# loglike =  tf.Tensor(-157.97443, shape=(), dtype=float32)
# v,a,w: 0.05402702838182449, 2.2087972164154053, 0.6050862669944763
# loglike =  tf.Tensor(-157.70601, shape=(), dtype=float32)
# v,a,w: 0.05402702838182449, 2.2087972164154053, 0.6050862669944763
# loglike =  tf.Tensor(-157.70601, shape=(), dtype=float32)
# v,a,w: 0.13392287492752075, 2.176088809967041, 0.587221086025238
# loglike =  tf.Tensor(-155.4292, shape=(), dtype=float32)
# v,a,w: 0.13392287492752075, 2.176088809967041, 0.587221086025238
# loglike =  tf.Tensor(-155.4292, shape=(), dtype=float32)
# v,a,w: -0.07668857276439667, 2.191592216491699, 0.5567468404769897
# loglike =  tf.Tensor(-158.98242, shape=(), dtype=float32)
# v,a,w: -0.07668857276439667, 2.191592216491699, 0.5567468404769897
# loglike =  tf.Tensor(-158.98242, shape=(), dtype=float32)
# v,a,w: -0.05864700302481651, 2.1438496112823486, 0.613965630531311
# loglike =  tf.Tensor(-158.95493, shape=(), dtype=float32)
# v,a,w: -0.05864700302481651, 2.1438496112823486, 0.613965630531311
# loglike =  tf.Tensor(-158.95493, shape=(), dtype=float32)
# v,a,w: -0.02427910640835762, 2.087611675262451, 0.6117076873779297
# loglike =  tf.Tensor(-157.9323, shape=(), dtype=float32)
# v,a,w: -0.02427910640835762, 2.087611675262451, 0.6117076873779297
# loglike =  tf.Tensor(-157.9323, shape=(), dtype=float32)
# v,a,w: 0.023389186710119247, 2.030061721801758, 0.5434961915016174
# loglike =  tf.Tensor(-154.93369, shape=(), dtype=float32)
# v,a,w: 0.023389186710119247, 2.030061721801758, 0.5434961915016174
# loglike =  tf.Tensor(-154.93369, shape=(), dtype=float32)
# v,a,w: 0.21784910559654236, 2.1308791637420654, 0.5098304152488708
# loglike =  tf.Tensor(-152.502, shape=(), dtype=float32)
# v,a,w: 0.21784910559654236, 2.1308791637420654, 0.5098304152488708
# loglike =  tf.Tensor(-152.502, shape=(), dtype=float32)
# v,a,w: 0.31272047758102417, 2.0743021965026855, 0.4518064856529236
# loglike =  tf.Tensor(-153.42958, shape=(), dtype=float32)
# v,a,w: 0.31272047758102417, 2.0743021965026855, 0.4518064856529236
# loglike =  tf.Tensor(-153.42958, shape=(), dtype=float32)
# v,a,w: 0.41990944743156433, 2.010230541229248, 0.4597538411617279
# loglike =  tf.Tensor(-152.20895, shape=(), dtype=float32)
# v,a,w: 0.41990944743156433, 2.010230541229248, 0.4597538411617279
# loglike =  tf.Tensor(-152.20895, shape=(), dtype=float32)
# v,a,w: 0.5268123745918274, 1.9511994123458862, 0.49849021434783936
# loglike =  tf.Tensor(-154.22945, shape=(), dtype=float32)
# v,a,w: 0.5268123745918274, 1.9511994123458862, 0.49849021434783936
# loglike =  tf.Tensor(-154.22945, shape=(), dtype=float32)
# v,a,w: 0.6155760884284973, 1.9114317893981934, 0.5004928708076477
# loglike =  tf.Tensor(-157.57956, shape=(), dtype=float32)
# v,a,w: 0.6155760884284973, 1.9114317893981934, 0.5004928708076477
# loglike =  tf.Tensor(-157.57956, shape=(), dtype=float32)
# v,a,w: 0.6770505309104919, 1.8995448350906372, 0.4461793601512909
# loglike =  tf.Tensor(-157.78229, shape=(), dtype=float32)
# v,a,w: 0.6770505309104919, 1.8995448350906372, 0.4461793601512909
# loglike =  tf.Tensor(-157.78229, shape=(), dtype=float32)
# v,a,w: 0.7147647142410278, 1.916383147239685, 0.384802907705307
# loglike =  tf.Tensor(-159.83292, shape=(), dtype=float32)
# v,a,w: 0.7147647142410278, 1.916383147239685, 0.384802907705307
# loglike =  tf.Tensor(-159.83292, shape=(), dtype=float32)
# v,a,w: 0.736277163028717, 1.9554364681243896, 0.3815135061740875
# loglike =  tf.Tensor(-159.6376, shape=(), dtype=float32)
# v,a,w: 0.736277163028717, 1.9554364681243896, 0.3815135061740875
# loglike =  tf.Tensor(-159.6376, shape=(), dtype=float32)
# v,a,w: -0.012676775455474854, 2.223006248474121, 0.5594727396965027
# loglike =  tf.Tensor(-157.73993, shape=(), dtype=float32)
# v,a,w: -0.012676775455474854, 2.223006248474121, 0.5594727396965027
# loglike =  tf.Tensor(-157.73993, shape=(), dtype=float32)
# v,a,w: 0.12829342484474182, 2.185889482498169, 0.5939085483551025
# loglike =  tf.Tensor(-156.05606, shape=(), dtype=float32)
# v,a,w: 0.12829342484474182, 2.185889482498169, 0.5939085483551025
# loglike =  tf.Tensor(-156.05606, shape=(), dtype=float32)
# v,a,w: 0.28004956245422363, 2.1051065921783447, 0.40933284163475037
# loglike =  tf.Tensor(-159.00995, shape=(), dtype=float32)
# v,a,w: 0.28004956245422363, 2.1051065921783447, 0.40933284163475037
# loglike =  tf.Tensor(-159.00995, shape=(), dtype=float32)
# v,a,w: -0.043677642941474915, 2.100270986557007, 0.6306748986244202
# loglike =  tf.Tensor(-159.82, shape=(), dtype=float32)
# v,a,w: -0.043677642941474915, 2.100270986557007, 0.6306748986244202
# loglike =  tf.Tensor(-159.82, shape=(), dtype=float32)
# v,a,w: 0.027099378407001495, 2.0018255710601807, 0.4182659387588501
# loglike =  tf.Tensor(-165.62996, shape=(), dtype=float32)
# v,a,w: 0.027099378407001495, 2.0018255710601807, 0.4182659387588501
# loglike =  tf.Tensor(-165.62996, shape=(), dtype=float32)
# v,a,w: 0.23968932032585144, 1.8824387788772583, 0.697201132774353
# loglike =  tf.Tensor(-177.75723, shape=(), dtype=float32)
# v,a,w: 0.23968932032585144, 1.8824387788772583, 0.697201132774353
# loglike =  tf.Tensor(-177.75723, shape=(), dtype=float32)
# v,a,w: 0.3646969199180603, 1.871166706085205, 0.19644272327423096
# loglike =  tf.Tensor(-211.75949, shape=(), dtype=float32)
# v,a,w: 0.3646969199180603, 1.871166706085205, 0.19644272327423096
# loglike =  tf.Tensor(-211.75949, shape=(), dtype=float32)
# v,a,w: -0.004191520623862743, 2.218186378479004, 0.5626518726348877
# loglike =  tf.Tensor(-157.3959, shape=(), dtype=float32)
# v,a,w: -0.004191520623862743, 2.218186378479004, 0.5626518726348877
# loglike =  tf.Tensor(-157.3959, shape=(), dtype=float32)
# v,a,w: -0.019021891057491302, 2.2259204387664795, 0.5571753978729248
# loglike =  tf.Tensor(-158.006, shape=(), dtype=float32)
# v,a,w: -0.019021891057491302, 2.2259204387664795, 0.5571753978729248
# loglike =  tf.Tensor(-158.006, shape=(), dtype=float32)
# v,a,w: -0.02312861755490303, 2.2268764972686768, 0.5561748147010803
# loglike =  tf.Tensor(-158.15804, shape=(), dtype=float32)
# v,a,w: -0.02312861755490303, 2.2268764972686768, 0.5561748147010803
# loglike =  tf.Tensor(-158.15804, shape=(), dtype=float32)
# v,a,w: -0.0249431524425745, 2.225853443145752, 0.5566741228103638
# loglike =  tf.Tensor(-158.17502, shape=(), dtype=float32)
# v,a,w: -0.0249431524425745, 2.225853443145752, 0.5566741228103638
# loglike =  tf.Tensor(-158.17502, shape=(), dtype=float32)
# v,a,w: -0.024460427463054657, 2.2228634357452393, 0.558638870716095
# loglike =  tf.Tensor(-158.0599, shape=(), dtype=float32)
# v,a,w: -0.024460427463054657, 2.2228634357452393, 0.558638870716095
# loglike =  tf.Tensor(-158.0599, shape=(), dtype=float32)
# v,a,w: -0.021723449230194092, 2.217952013015747, 0.5618013143539429
# loglike =  tf.Tensor(-157.83817, shape=(), dtype=float32)
# v,a,w: -0.021723449230194092, 2.217952013015747, 0.5618013143539429
# loglike =  tf.Tensor(-157.83817, shape=(), dtype=float32)
# v,a,w: -0.01681777462363243, 2.2111945152282715, 0.5656943321228027
# loglike =  tf.Tensor(-157.5465, shape=(), dtype=float32)
# v,a,w: -0.01681777462363243, 2.2111945152282715, 0.5656943321228027
# loglike =  tf.Tensor(-157.5465, shape=(), dtype=float32)
# v,a,w: -0.0479581281542778, 2.223862409591675, 0.5674625039100647
# loglike =  tf.Tensor(-158.63339, shape=(), dtype=float32)
# v,a,w: -0.0479581281542778, 2.223862409591675, 0.5674625039100647
# loglike =  tf.Tensor(-158.63339, shape=(), dtype=float32)
# v,a,w: -0.06499531120061874, 2.2221977710723877, 0.5754280090332031
# loglike =  tf.Tensor(-159.04373, shape=(), dtype=float32)
# v,a,w: -0.06499531120061874, 2.2221977710723877, 0.5754280090332031
# loglike =  tf.Tensor(-159.04373, shape=(), dtype=float32)
# v,a,w: -0.07285480201244354, 2.213200092315674, 0.5830190777778625
# loglike =  tf.Tensor(-159.11319, shape=(), dtype=float32)
# v,a,w: -0.07285480201244354, 2.213200092315674, 0.5830190777778625
# loglike =  tf.Tensor(-159.11319, shape=(), dtype=float32)
# v,a,w: 0.013221628963947296, 2.204627275466919, 0.5590744018554688
# loglike =  tf.Tensor(-156.70834, shape=(), dtype=float32)
# v,a,w: 0.013221628963947296, 2.204627275466919, 0.5590744018554688
# loglike =  tf.Tensor(-156.70834, shape=(), dtype=float32)
# v,a,w: 0.05585102364420891, 2.1844770908355713, 0.557630181312561
# loglike =  tf.Tensor(-155.42737, shape=(), dtype=float32)
# v,a,w: 0.05585102364420891, 2.1844770908355713, 0.557630181312561
# loglike =  tf.Tensor(-155.42737, shape=(), dtype=float32)
# v,a,w: 0.10475825518369675, 2.158458948135376, 0.5544741749763489
# loglike =  tf.Tensor(-154.17444, shape=(), dtype=float32)
# v,a,w: 0.10475825518369675, 2.158458948135376, 0.5544741749763489
# loglike =  tf.Tensor(-154.17444, shape=(), dtype=float32)
# v,a,w: 0.15842390060424805, 2.127795457839966, 0.5468576550483704
# loglike =  tf.Tensor(-153.0387, shape=(), dtype=float32)
# v,a,w: 0.15842390060424805, 2.127795457839966, 0.5468576550483704
# loglike =  tf.Tensor(-153.0387, shape=(), dtype=float32)
# v,a,w: 0.15745550394058228, 2.042994737625122, 0.4404793083667755
# loglike =  tf.Tensor(-157.69608, shape=(), dtype=float32)
# v,a,w: 0.15745550394058228, 2.042994737625122, 0.4404793083667755
# loglike =  tf.Tensor(-157.69608, shape=(), dtype=float32)
# v,a,w: 0.17436765134334564, 2.1981687545776367, 0.6285414695739746
# loglike =  tf.Tensor(-159.9691, shape=(), dtype=float32)
# v,a,w: 0.17436765134334564, 2.1981687545776367, 0.6285414695739746
# loglike =  tf.Tensor(-159.9691, shape=(), dtype=float32)
# v,a,w: 0.17765560746192932, 2.247080087661743, 0.5091263055801392
# loglike =  tf.Tensor(-155.52348, shape=(), dtype=float32)
# v,a,w: 0.17765560746192932, 2.247080087661743, 0.5091263055801392
# loglike =  tf.Tensor(-155.52348, shape=(), dtype=float32)
# v,a,w: 0.20773226022720337, 2.254235029220581, 0.45271027088165283
# loglike =  tf.Tensor(-159.55463, shape=(), dtype=float32)
# v,a,w: 0.20773226022720337, 2.254235029220581, 0.45271027088165283
# loglike =  tf.Tensor(-159.55463, shape=(), dtype=float32)
# v,a,w: 0.2790484130382538, 2.208936929702759, 0.5688214898109436
# loglike =  tf.Tensor(-154.8233, shape=(), dtype=float32)
# v,a,w: 0.2790484130382538, 2.208936929702759, 0.5688214898109436
# loglike =  tf.Tensor(-154.8233, shape=(), dtype=float32)
# v,a,w: 0.34158146381378174, 2.1377182006835938, 0.5835934281349182
# loglike =  tf.Tensor(-155.932, shape=(), dtype=float32)
# v,a,w: 0.34158146381378174, 2.1377182006835938, 0.5835934281349182
# loglike =  tf.Tensor(-155.932, shape=(), dtype=float32)
# v,a,w: 0.3802359104156494, 2.0559804439544678, 0.4406037926673889
# loglike =  tf.Tensor(-153.36534, shape=(), dtype=float32)
# v,a,w: 0.3802359104156494, 2.0559804439544678, 0.4406037926673889
# loglike =  tf.Tensor(-153.36534, shape=(), dtype=float32)
# v,a,w: 0.2648208737373352, 2.2043135166168213, 0.5500993132591248
# loglike =  tf.Tensor(-153.69112, shape=(), dtype=float32)
# v,a,w: 0.2648208737373352, 2.2043135166168213, 0.5500993132591248
# loglike =  tf.Tensor(-153.69112, shape=(), dtype=float32)
# v,a,w: 0.25056883692741394, 2.1986308097839355, 0.5291312336921692
# loglike =  tf.Tensor(-153.14879, shape=(), dtype=float32)
# v,a,w: 0.25056883692741394, 2.1986308097839355, 0.5291312336921692
# loglike =  tf.Tensor(-153.14879, shape=(), dtype=float32)
# v,a,w: 0.23663915693759918, 2.1918275356292725, 0.507793664932251
# loglike =  tf.Tensor(-153.34076, shape=(), dtype=float32)
# v,a,w: 0.23663915693759918, 2.1918275356292725, 0.507793664932251
# loglike =  tf.Tensor(-153.34076, shape=(), dtype=float32)
# v,a,w: 0.2929314374923706, 2.212543487548828, 0.5835688710212708
# loglike =  tf.Tensor(-156.19269, shape=(), dtype=float32)
# v,a,w: 0.2929314374923706, 2.212543487548828, 0.5835688710212708
# loglike =  tf.Tensor(-156.19269, shape=(), dtype=float32)
# v,a,w: 0.3062014877796173, 2.215157985687256, 0.5929192304611206
# loglike =  tf.Tensor(-157.34943, shape=(), dtype=float32)
# v,a,w: 0.3062014877796173, 2.215157985687256, 0.5929192304611206
# loglike =  tf.Tensor(-157.34943, shape=(), dtype=float32)
# v,a,w: 0.3186618983745575, 2.216790199279785, 0.5959003567695618
# loglike =  tf.Tensor(-157.90158, shape=(), dtype=float32)
# v,a,w: 0.3186618983745575, 2.216790199279785, 0.5959003567695618
# loglike =  tf.Tensor(-157.90158, shape=(), dtype=float32)
# v,a,w: 0.3302018940448761, 2.217440128326416, 0.5920956134796143
# loglike =  tf.Tensor(-157.65826, shape=(), dtype=float32)
# v,a,w: 0.3302018940448761, 2.217440128326416, 0.5920956134796143
# loglike =  tf.Tensor(-157.65826, shape=(), dtype=float32)
# v,a,w: 0.3408028483390808, 2.2171008586883545, 0.5816898345947266
# loglike =  tf.Tensor(-156.7008, shape=(), dtype=float32)
# v,a,w: 0.3408028483390808, 2.2171008586883545, 0.5816898345947266
# loglike =  tf.Tensor(-156.7008, shape=(), dtype=float32)
# v,a,w: 0.3505359888076782, 2.215757131576538, 0.5654453039169312
# loglike =  tf.Tensor(-155.34952, shape=(), dtype=float32)
# v,a,w: 0.3505359888076782, 2.215757131576538, 0.5654453039169312
# loglike =  tf.Tensor(-155.34952, shape=(), dtype=float32)
# v,a,w: 0.3595519959926605, 2.213380813598633, 0.5446150898933411
# loglike =  tf.Tensor(-154.04411, shape=(), dtype=float32)
# v,a,w: 0.3595519959926605, 2.213380813598633, 0.5446150898933411
# loglike =  tf.Tensor(-154.04411, shape=(), dtype=float32)
# v,a,w: 0.3680635690689087, 2.2099268436431885, 0.5208146572113037
# loglike =  tf.Tensor(-153.19029, shape=(), dtype=float32)
# v,a,w: 0.3680635690689087, 2.2099268436431885, 0.5208146572113037
# loglike =  tf.Tensor(-153.19029, shape=(), dtype=float32)
# v,a,w: 0.3763229548931122, 2.2053306102752686, 0.49587303400039673
# loglike =  tf.Tensor(-153.03012, shape=(), dtype=float32)
# v,a,w: 0.3763229548931122, 2.2053306102752686, 0.49587303400039673
# loglike =  tf.Tensor(-153.03012, shape=(), dtype=float32)
# v,a,w: 0.3845963478088379, 2.199511766433716, 0.47168073058128357
# loglike =  tf.Tensor(-153.57309, shape=(), dtype=float32)
# v,a,w: 0.3845963478088379, 2.199511766433716, 0.47168073058128357
# loglike =  tf.Tensor(-153.57309, shape=(), dtype=float32)
# v,a,w: 0.39313754439353943, 2.1923844814300537, 0.4500422179698944
# loglike =  tf.Tensor(-154.60124, shape=(), dtype=float32)
# v,a,w: 0.39313754439353943, 2.1923844814300537, 0.4500422179698944
# loglike =  tf.Tensor(-154.60124, shape=(), dtype=float32)
# v,a,w: 0.402163028717041, 2.1838741302490234, 0.43253788352012634
# loglike =  tf.Tensor(-155.74228, shape=(), dtype=float32)
# v,a,w: 0.402163028717041, 2.1838741302490234, 0.43253788352012634
# loglike =  tf.Tensor(-155.74228, shape=(), dtype=float32)
# v,a,w: 0.41183042526245117, 2.173936128616333, 0.4203999936580658
# loglike =  tf.Tensor(-156.58987, shape=(), dtype=float32)
# v,a,w: 0.41183042526245117, 2.173936128616333, 0.4203999936580658
# loglike =  tf.Tensor(-156.58987, shape=(), dtype=float32)
# v,a,w: 0.4222221374511719, 2.1625730991363525, 0.4144112467765808
# loglike =  tf.Tensor(-156.83624, shape=(), dtype=float32)
# v,a,w: 0.4222221374511719, 2.1625730991363525, 0.4144112467765808
# loglike =  tf.Tensor(-156.83624, shape=(), dtype=float32)
# v,a,w: 0.43333572149276733, 2.149848222732544, 0.41483792662620544
# loglike =  tf.Tensor(-156.37479, shape=(), dtype=float32)
# v,a,w: 0.43333572149276733, 2.149848222732544, 0.41483792662620544
# loglike =  tf.Tensor(-156.37479, shape=(), dtype=float32)
# v,a,w: 0.4450817406177521, 2.135887384414673, 0.42141029238700867
# loglike =  tf.Tensor(-155.3351, shape=(), dtype=float32)
# v,a,w: 0.4450817406177521, 2.135887384414673, 0.42141029238700867
# loglike =  tf.Tensor(-155.3351, shape=(), dtype=float32)
# v,a,w: 0.4572891891002655, 2.1208746433258057, 0.43335554003715515
# loglike =  tf.Tensor(-154.03624, shape=(), dtype=float32)
# v,a,w: 0.4572891891002655, 2.1208746433258057, 0.43335554003715515
# loglike =  tf.Tensor(-154.03624, shape=(), dtype=float32)
# v,a,w: 0.46971797943115234, 2.1050384044647217, 0.4494780898094177
# loglike =  tf.Tensor(-152.87766, shape=(), dtype=float32)
# v,a,w: 0.46971797943115234, 2.1050384044647217, 0.4494780898094177
# loglike =  tf.Tensor(-152.87766, shape=(), dtype=float32)
# v,a,w: 0.4820767045021057, 2.0886332988739014, 0.46827322244644165
# loglike =  tf.Tensor(-152.21027, shape=(), dtype=float32)
# v,a,w: 0.4820767045021057, 2.0886332988739014, 0.46827322244644165
# loglike =  tf.Tensor(-152.21027, shape=(), dtype=float32)
# v,a,w: 0.49404439330101013, 2.0719223022460938, 0.48805758357048035
# loglike =  tf.Tensor(-152.23177, shape=(), dtype=float32)
# v,a,w: 0.49404439330101013, 2.0719223022460938, 0.48805758357048035
# loglike =  tf.Tensor(-152.23177, shape=(), dtype=float32)
# v,a,w: 0.5052937269210815, 2.0551609992980957, 0.5071037411689758
# loglike =  tf.Tensor(-152.93457, shape=(), dtype=float32)
# v,a,w: 0.5052937269210815, 2.0551609992980957, 0.5071037411689758
# loglike =  tf.Tensor(-152.93457, shape=(), dtype=float32)
# v,a,w: 0.515514075756073, 2.0385875701904297, 0.5237705707550049
# loglike =  tf.Tensor(-154.11589, shape=(), dtype=float32)
# v,a,w: 0.515514075756073, 2.0385875701904297, 0.5237705707550049
# loglike =  tf.Tensor(-154.11589, shape=(), dtype=float32)
# v,a,w: 0.5244329571723938, 2.0224177837371826, 0.5366246700286865
# loglike =  tf.Tensor(-155.44296, shape=(), dtype=float32)
# v,a,w: 0.5244329571723938, 2.0224177837371826, 0.5366246700286865
# loglike =  tf.Tensor(-155.44296, shape=(), dtype=float32)
# v,a,w: 0.5318337082862854, 2.006845712661743, 0.5445472002029419
# loglike =  tf.Tensor(-156.55392, shape=(), dtype=float32)
# v,a,w: 0.5318337082862854, 2.006845712661743, 0.5445472002029419
# loglike =  tf.Tensor(-156.55392, shape=(), dtype=float32)
# v,a,w: 0.5375686287879944, 1.9920451641082764, 0.5468188524246216
# loglike =  tf.Tensor(-157.16602, shape=(), dtype=float32)
# v,a,w: 0.5375686287879944, 1.9920451641082764, 0.5468188524246216
# loglike =  tf.Tensor(-157.16602, shape=(), dtype=float32)
# v,a,w: 0.5415670871734619, 1.9781720638275146, 0.543173611164093
# loglike =  tf.Tensor(-157.15813, shape=(), dtype=float32)
# v,a,w: 0.5415670871734619, 1.9781720638275146, 0.543173611164093
# loglike =  tf.Tensor(-157.15813, shape=(), dtype=float32)
# v,a,w: 0.5438374280929565, 1.9653640985488892, 0.5338131785392761
# loglike =  tf.Tensor(-156.60144, shape=(), dtype=float32)
# v,a,w: 0.5438374280929565, 1.9653640985488892, 0.5338131785392761
# loglike =  tf.Tensor(-156.60144, shape=(), dtype=float32)
# v,a,w: 0.5444635152816772, 1.9537389278411865, 0.5193809866905212
# loglike =  tf.Tensor(-155.72958, shape=(), dtype=float32)
# v,a,w: 0.5444635152816772, 1.9537389278411865, 0.5193809866905212
# loglike =  tf.Tensor(-155.72958, shape=(), dtype=float32)
# v,a,w: 0.5435958504676819, 1.9433891773223877, 0.50090092420578
# loglike =  tf.Tensor(-154.86215, shape=(), dtype=float32)
# v,a,w: 0.5435958504676819, 1.9433891773223877, 0.50090092420578
# loglike =  tf.Tensor(-154.86215, shape=(), dtype=float32)
# v,a,w: 0.5414385795593262, 1.9343780279159546, 0.4796924293041229
# loglike =  tf.Tensor(-154.30869, shape=(), dtype=float32)
# v,a,w: 0.5414385795593262, 1.9343780279159546, 0.4796924293041229
# loglike =  tf.Tensor(-154.30869, shape=(), dtype=float32)
# v,a,w: 0.5382332801818848, 1.9267362356185913, 0.457272469997406
# loglike =  tf.Tensor(-154.28166, shape=(), dtype=float32)
# v,a,w: 0.5382332801818848, 1.9267362356185913, 0.457272469997406
# loglike =  tf.Tensor(-154.28166, shape=(), dtype=float32)
# v,a,w: 0.5342406034469604, 1.9204624891281128, 0.43525248765945435
# loglike =  tf.Tensor(-154.83893, shape=(), dtype=float32)
# v,a,w: 0.5342406034469604, 1.9204624891281128, 0.43525248765945435
# loglike =  tf.Tensor(-154.83893, shape=(), dtype=float32)
# v,a,w: 0.5297212600708008, 1.9155282974243164, 0.4152328372001648
# loglike =  tf.Tensor(-155.86618, shape=(), dtype=float32)
# v,a,w: 0.5297212600708008, 1.9155282974243164, 0.4152328372001648
# loglike =  tf.Tensor(-155.86618, shape=(), dtype=float32)
# v,a,w: 0.5249173045158386, 1.9118871688842773, 0.3986954987049103
# loglike =  tf.Tensor(-157.10345, shape=(), dtype=float32)
# v,a,w: 0.5249173045158386, 1.9118871688842773, 0.3986954987049103
# loglike =  tf.Tensor(-157.10345, shape=(), dtype=float32)
# v,a,w: 0.5200347304344177, 1.9094862937927246, 0.3868958353996277
# loglike =  tf.Tensor(-158.2128, shape=(), dtype=float32)
# v,a,w: 0.5200347304344177, 1.9094862937927246, 0.3868958353996277
# loglike =  tf.Tensor(-158.2128, shape=(), dtype=float32)
# v,a,w: 0.5152290463447571, 1.9082791805267334, 0.3807598948478699
# loglike =  tf.Tensor(-158.87453, shape=(), dtype=float32)
# v,a,w: 0.5152290463447571, 1.9082791805267334, 0.3807598948478699
# loglike =  tf.Tensor(-158.87453, shape=(), dtype=float32)
# v,a,w: 0.5105943083763123, 1.9082356691360474, 0.380799800157547
# loglike =  tf.Tensor(-158.88586, shape=(), dtype=float32)
# v,a,w: 0.5105943083763123, 1.9082356691360474, 0.380799800157547
# loglike =  tf.Tensor(-158.88586, shape=(), dtype=float32)
# v,a,w: 0.5061572194099426, 1.909348964691162, 0.3870634436607361
# loglike =  tf.Tensor(-158.22693, shape=(), dtype=float32)
# v,a,w: 0.5061572194099426, 1.909348964691162, 0.3870634436607361
# loglike =  tf.Tensor(-158.22693, shape=(), dtype=float32)
# v,a,w: 0.5018764734268188, 1.9116358757019043, 0.39913082122802734
# loglike =  tf.Tensor(-157.06696, shape=(), dtype=float32)
# v,a,w: 0.5018764734268188, 1.9116358757019043, 0.39913082122802734
# loglike =  tf.Tensor(-157.06696, shape=(), dtype=float32)
# v,a,w: 0.4976472854614258, 1.9151325225830078, 0.41615718603134155
# loglike =  tf.Tensor(-155.70865, shape=(), dtype=float32)
# v,a,w: 0.4976472854614258, 1.9151325225830078, 0.41615718603134155
# loglike =  tf.Tensor(-155.70865, shape=(), dtype=float32)
# v,a,w: 0.4933110475540161, 1.9198848009109497, 0.4369519352912903
# loglike =  tf.Tensor(-154.49452, shape=(), dtype=float32)
# v,a,w: 0.4933110475540161, 1.9198848009109497, 0.4369519352912903
# loglike =  tf.Tensor(-154.49452, shape=(), dtype=float32)
# v,a,w: 0.48866894841194153, 1.9259363412857056, 0.46007686853408813
# loglike =  tf.Tensor(-153.70963, shape=(), dtype=float32)
# v,a,w: 0.48866894841194153, 1.9259363412857056, 0.46007686853408813
# loglike =  tf.Tensor(-153.70963, shape=(), dtype=float32)
# v,a,w: 0.48349836468696594, 1.933316707611084, 0.483950674533844
# loglike =  tf.Tensor(-153.50763, shape=(), dtype=float32)
# v,a,w: 0.48349836468696594, 1.933316707611084, 0.483950674533844
# loglike =  tf.Tensor(-153.50763, shape=(), dtype=float32)
# v,a,w: 0.4775712490081787, 1.9420310258865356, 0.5069534778594971
# loglike =  tf.Tensor(-153.87424, shape=(), dtype=float32)
# v,a,w: 0.4775712490081787, 1.9420310258865356, 0.5069534778594971
# loglike =  tf.Tensor(-153.87424, shape=(), dtype=float32)
# v,a,w: 0.5366425514221191, 1.9583338499069214, 0.5315091609954834
# loglike =  tf.Tensor(-156.3516, shape=(), dtype=float32)
# v,a,w: 0.5366425514221191, 1.9583338499069214, 0.5315091609954834
# loglike =  tf.Tensor(-156.3516, shape=(), dtype=float32)
# v,a,w: 0.5441682934761047, 1.9773316383361816, 0.514944851398468
# loglike =  tf.Tensor(-154.96173, shape=(), dtype=float32)
# v,a,w: 0.5441682934761047, 1.9773316383361816, 0.514944851398468
# loglike =  tf.Tensor(-154.96173, shape=(), dtype=float32)
# v,a,w: 0.5385687947273254, 1.9935216903686523, 0.48080143332481384
# loglike =  tf.Tensor(-153.21661, shape=(), dtype=float32)
# v,a,w: 0.5385687947273254, 1.9935216903686523, 0.48080143332481384
# loglike =  tf.Tensor(-153.21661, shape=(), dtype=float32)
# v,a,w: 0.6104800701141357, 2.0368099212646484, 0.48572227358818054
# loglike =  tf.Tensor(-154.41716, shape=(), dtype=float32)
# v,a,w: 0.6104800701141357, 2.0368099212646484, 0.48572227358818054
# loglike =  tf.Tensor(-154.41716, shape=(), dtype=float32)
# v,a,w: 0.6535235643386841, 2.088088274002075, 0.448016494512558
# loglike =  tf.Tensor(-154.74725, shape=(), dtype=float32)
# v,a,w: 0.6535235643386841, 2.088088274002075, 0.448016494512558
# loglike =  tf.Tensor(-154.74725, shape=(), dtype=float32)
# v,a,w: 0.6729750633239746, 2.135481834411621, 0.4197702407836914
# loglike =  tf.Tensor(-156.22217, shape=(), dtype=float32)
# v,a,w: 0.6729750633239746, 2.135481834411621, 0.4197702407836914
# loglike =  tf.Tensor(-156.22217, shape=(), dtype=float32)
# v,a,w: 0.44664478302001953, 1.965070128440857, 0.4546123147010803
# loglike =  tf.Tensor(-152.85605, shape=(), dtype=float32)
# v,a,w: 0.44664478302001953, 1.965070128440857, 0.4546123147010803
# loglike =  tf.Tensor(-152.85605, shape=(), dtype=float32)
# v,a,w: 0.3512086868286133, 1.9530888795852661, 0.46522989869117737
# loglike =  tf.Tensor(-152.7441, shape=(), dtype=float32)
# v,a,w: 0.3512086868286133, 1.9530888795852661, 0.46522989869117737
# loglike =  tf.Tensor(-152.7441, shape=(), dtype=float32)
# v,a,w: 0.2609620690345764, 1.9590258598327637, 0.5178120136260986
# loglike =  tf.Tensor(-152.38358, shape=(), dtype=float32)
# v,a,w: 0.2609620690345764, 1.9590258598327637, 0.5178120136260986
# loglike =  tf.Tensor(-152.38358, shape=(), dtype=float32)
# v,a,w: 0.17468667030334473, 1.9846748113632202, 0.5560314655303955
# loglike =  tf.Tensor(-153.39069, shape=(), dtype=float32)
# v,a,w: 0.17468667030334473, 1.9846748113632202, 0.5560314655303955
# loglike =  tf.Tensor(-153.39069, shape=(), dtype=float32)
# v,a,w: 0.674889862537384, 2.1679556369781494, 0.446334570646286
# loglike =  tf.Tensor(-155.91647, shape=(), dtype=float32)
# v,a,w: 0.674889862537384, 2.1679556369781494, 0.446334570646286
# loglike =  tf.Tensor(-155.91647, shape=(), dtype=float32)
# v,a,w: 0.653178334236145, 2.1830406188964844, 0.4877316653728485
# loglike =  tf.Tensor(-156.1608, shape=(), dtype=float32)
# v,a,w: 0.653178334236145, 2.1830406188964844, 0.4877316653728485
# loglike =  tf.Tensor(-156.1608, shape=(), dtype=float32)
# v,a,w: 0.6001425981521606, 2.1816294193267822, 0.4837232232093811
# loglike =  tf.Tensor(-154.78354, shape=(), dtype=float32)
# v,a,w: 0.6001425981521606, 2.1816294193267822, 0.4837232232093811
# loglike =  tf.Tensor(-154.78354, shape=(), dtype=float32)
# v,a,w: 0.523158848285675, 2.1624481678009033, 0.4544244408607483
# loglike =  tf.Tensor(-153.64206, shape=(), dtype=float32)
# v,a,w: 0.523158848285675, 2.1624481678009033, 0.4544244408607483
# loglike =  tf.Tensor(-153.64206, shape=(), dtype=float32)
# v,a,w: 0.43855637311935425, 2.123734474182129, 0.4651496708393097
# loglike =  tf.Tensor(-152.42017, shape=(), dtype=float32)
# v,a,w: 0.43855637311935425, 2.123734474182129, 0.4651496708393097
# loglike =  tf.Tensor(-152.42017, shape=(), dtype=float32)
# v,a,w: 0.35281074047088623, 2.0711517333984375, 0.5157140493392944
# loglike =  tf.Tensor(-151.53546, shape=(), dtype=float32)
# v,a,w: 0.35281074047088623, 2.0711517333984375, 0.5157140493392944
# loglike =  tf.Tensor(-151.53546, shape=(), dtype=float32)
# v,a,w: 0.26253968477249146, 2.0172581672668457, 0.5427805185317993
# loglike =  tf.Tensor(-152.32, shape=(), dtype=float32)
# v,a,w: 0.26253968477249146, 2.0172581672668457, 0.5427805185317993
# loglike =  tf.Tensor(-152.32, shape=(), dtype=float32)
# v,a,w: 0.17113356292247772, 1.9729329347610474, 0.521827757358551
# loglike =  tf.Tensor(-152.88297, shape=(), dtype=float32)
# v,a,w: 0.17113356292247772, 1.9729329347610474, 0.521827757358551
# loglike =  tf.Tensor(-152.88297, shape=(), dtype=float32)
# v,a,w: 0.09380104392766953, 1.9440505504608154, 0.5026777982711792
# loglike =  tf.Tensor(-155.02791, shape=(), dtype=float32)
# v,a,w: 0.09380104392766953, 1.9440505504608154, 0.5026777982711792
# loglike =  tf.Tensor(-155.02791, shape=(), dtype=float32)
# v,a,w: 0.04373445734381676, 1.933578610420227, 0.5287488102912903
# loglike =  tf.Tensor(-155.67264, shape=(), dtype=float32)
# v,a,w: 0.04373445734381676, 1.933578610420227, 0.5287488102912903
# loglike =  tf.Tensor(-155.67264, shape=(), dtype=float32)
# v,a,w: 0.020768560469150543, 1.9458190202713013, 0.5718791484832764
# loglike =  tf.Tensor(-156.33275, shape=(), dtype=float32)
# v,a,w: 0.020768560469150543, 1.9458190202713013, 0.5718791484832764
# loglike =  tf.Tensor(-156.33275, shape=(), dtype=float32)
# v,a,w: 0.017925141379237175, 1.9816194772720337, 0.573162317276001
# loglike =  tf.Tensor(-155.83084, shape=(), dtype=float32)
# v,a,w: 0.017925141379237175, 1.9816194772720337, 0.573162317276001
# loglike =  tf.Tensor(-155.83084, shape=(), dtype=float32)
# v,a,w: 0.03566066175699234, 2.0333375930786133, 0.5341541171073914
# loglike =  tf.Tensor(-154.75623, shape=(), dtype=float32)
# v,a,w: 0.03566066175699234, 2.0333375930786133, 0.5341541171073914
# loglike =  tf.Tensor(-154.75623, shape=(), dtype=float32)
# v,a,w: 0.08183395862579346, 2.0871658325195312, 0.5164052844047546
# loglike =  tf.Tensor(-154.30148, shape=(), dtype=float32)
# v,a,w: 0.08183395862579346, 2.0871658325195312, 0.5164052844047546
# loglike =  tf.Tensor(-154.30148, shape=(), dtype=float32)
# v,a,w: 0.15615326166152954, 2.1319282054901123, 0.5424487590789795
# loglike =  tf.Tensor(-153.04688, shape=(), dtype=float32)
# v,a,w: 0.15615326166152954, 2.1319282054901123, 0.5424487590789795
# loglike =  tf.Tensor(-153.04688, shape=(), dtype=float32)
# v,a,w: 0.24392855167388916, 2.1639983654022217, 0.5568309426307678
# loglike =  tf.Tensor(-153.34042, shape=(), dtype=float32)
# v,a,w: 0.24392855167388916, 2.1639983654022217, 0.5568309426307678
# loglike =  tf.Tensor(-153.34042, shape=(), dtype=float32)
# v,a,w: 0.6004670858383179, 2.1664624214172363, 0.46920478343963623
# loglike =  tf.Tensor(-154.39441, shape=(), dtype=float32)
# v,a,w: 0.6004670858383179, 2.1664624214172363, 0.46920478343963623
# loglike =  tf.Tensor(-154.39441, shape=(), dtype=float32)
# v,a,w: 0.6185333132743835, 2.1536142826080322, 0.3796323537826538
# loglike =  tf.Tensor(-159.37247, shape=(), dtype=float32)
# v,a,w: 0.6185333132743835, 2.1536142826080322, 0.3796323537826538
# loglike =  tf.Tensor(-159.37247, shape=(), dtype=float32)
# v,a,w: 0.5832753777503967, 2.0533998012542725, 0.6559427380561829
# loglike =  tf.Tensor(-178.18347, shape=(), dtype=float32)
# v,a,w: 0.5832753777503967, 2.0533998012542725, 0.6559427380561829
# loglike =  tf.Tensor(-178.18347, shape=(), dtype=float32)
# v,a,w: 0.5763983726501465, 2.1608335971832275, 0.45110946893692017
# loglike =  tf.Tensor(-154.18442, shape=(), dtype=float32)
# v,a,w: 0.5763983726501465, 2.1608335971832275, 0.45110946893692017
# loglike =  tf.Tensor(-154.18442, shape=(), dtype=float32)
# v,a,w: 0.5495105981826782, 2.15130352973938, 0.43975237011909485
# loglike =  tf.Tensor(-154.22095, shape=(), dtype=float32)
# v,a,w: 0.5495105981826782, 2.15130352973938, 0.43975237011909485
# loglike =  tf.Tensor(-154.22095, shape=(), dtype=float32)
# v,a,w: 0.5210583209991455, 2.1377742290496826, 0.4402812123298645
# loglike =  tf.Tensor(-153.84909, shape=(), dtype=float32)
# v,a,w: 0.5210583209991455, 2.1377742290496826, 0.4402812123298645
# loglike =  tf.Tensor(-153.84909, shape=(), dtype=float32)
# v,a,w: 0.4916636645793915, 2.120586633682251, 0.45370060205459595
# loglike =  tf.Tensor(-152.92203, shape=(), dtype=float32)
# v,a,w: 0.4916636645793915, 2.120586633682251, 0.45370060205459595
# loglike =  tf.Tensor(-152.92203, shape=(), dtype=float32)
# v,a,w: 0.46126091480255127, 2.100555896759033, 0.4765753448009491
# loglike =  tf.Tensor(-152.02942, shape=(), dtype=float32)
# v,a,w: 0.46126091480255127, 2.100555896759033, 0.4765753448009491
# loglike =  tf.Tensor(-152.02942, shape=(), dtype=float32)
# v,a,w: 0.4293050765991211, 2.078810691833496, 0.5023578405380249
# loglike =  tf.Tensor(-151.7761, shape=(), dtype=float32)
# v,a,w: 0.4293050765991211, 2.078810691833496, 0.5023578405380249
# loglike =  tf.Tensor(-151.7761, shape=(), dtype=float32)
# v,a,w: 0.39515388011932373, 2.0565550327301025, 0.523698627948761
# loglike =  tf.Tensor(-152.0761, shape=(), dtype=float32)
# v,a,w: 0.39515388011932373, 2.0565550327301025, 0.523698627948761
# loglike =  tf.Tensor(-152.0761, shape=(), dtype=float32)
# v,a,w: 0.358478844165802, 2.034890651702881, 0.5349079966545105
# loglike =  tf.Tensor(-152.31705, shape=(), dtype=float32)
# v,a,w: 0.358478844165802, 2.034890651702881, 0.5349079966545105
# loglike =  tf.Tensor(-152.31705, shape=(), dtype=float32)
# v,a,w: 0.3195634186267853, 2.014733076095581, 0.5338306427001953
# loglike =  tf.Tensor(-152.1475, shape=(), dtype=float32)
# v,a,w: 0.3195634186267853, 2.014733076095581, 0.5338306427001953
# loglike =  tf.Tensor(-152.1475, shape=(), dtype=float32)
# v,a,w: 0.27939143776893616, 1.9967739582061768, 0.5225086808204651
# loglike =  tf.Tensor(-151.90558, shape=(), dtype=float32)
# v,a,w: 0.27939143776893616, 1.9967739582061768, 0.5225086808204651
# loglike =  tf.Tensor(-151.90558, shape=(), dtype=float32)
# v,a,w: 0.23950272798538208, 1.9814566373825073, 0.5063729882240295
# loglike =  tf.Tensor(-152.17091, shape=(), dtype=float32)
# v,a,w: 0.23950272798538208, 1.9814566373825073, 0.5063729882240295
# loglike =  tf.Tensor(-152.17091, shape=(), dtype=float32)
# v,a,w: 0.20167139172554016, 1.968998670578003, 0.49232640862464905
# loglike =  tf.Tensor(-153.0289, shape=(), dtype=float32)
# v,a,w: 0.20167139172554016, 1.968998670578003, 0.49232640862464905
# loglike =  tf.Tensor(-153.0289, shape=(), dtype=float32)
# v,a,w: 0.16751521825790405, 1.9595030546188354, 0.486456036567688
# loglike =  tf.Tensor(-153.94388, shape=(), dtype=float32)
# v,a,w: 0.16751521825790405, 1.9595030546188354, 0.486456036567688
# loglike =  tf.Tensor(-153.94388, shape=(), dtype=float32)
# v,a,w: 0.13815820217132568, 1.9531222581863403, 0.49208784103393555
# loglike =  tf.Tensor(-154.35857, shape=(), dtype=float32)
# v,a,w: 0.13815820217132568, 1.9531222581863403, 0.49208784103393555
# loglike =  tf.Tensor(-154.35857, shape=(), dtype=float32)
# v,a,w: 0.11404531449079514, 1.950166940689087, 0.508741021156311
# loglike =  tf.Tensor(-154.30106, shape=(), dtype=float32)
# v,a,w: 0.11404531449079514, 1.950166940689087, 0.508741021156311
# loglike =  tf.Tensor(-154.30106, shape=(), dtype=float32)
# v,a,w: 0.09496030956506729, 1.951072096824646, 0.5322829484939575
# loglike =  tf.Tensor(-154.30211, shape=(), dtype=float32)
# v,a,w: 0.09496030956506729, 1.951072096824646, 0.5322829484939575
# loglike =  tf.Tensor(-154.30211, shape=(), dtype=float32)
# v,a,w: 0.08023478090763092, 1.9562336206436157, 0.5561959743499756
# loglike =  tf.Tensor(-154.73416, shape=(), dtype=float32)
# v,a,w: 0.08023478090763092, 1.9562336206436157, 0.5561959743499756
# loglike =  tf.Tensor(-154.73416, shape=(), dtype=float32)
# v,a,w: 0.0690813958644867, 1.9658184051513672, 0.5735807418823242
# loglike =  tf.Tensor(-155.33618, shape=(), dtype=float32)
# v,a,w: 0.0690813958644867, 1.9658184051513672, 0.5735807418823242
# loglike =  tf.Tensor(-155.33618, shape=(), dtype=float32)
# v,a,w: 0.060949549078941345, 1.97964608669281, 0.5794081687927246
# loglike =  tf.Tensor(-155.49744, shape=(), dtype=float32)
# v,a,w: 0.060949549078941345, 1.97964608669281, 0.5794081687927246
# loglike =  tf.Tensor(-155.49744, shape=(), dtype=float32)
# v,a,w: 0.055789750069379807, 1.9971641302108765, 0.5723408460617065
# loglike =  tf.Tensor(-155.01942, shape=(), dtype=float32)
# v,a,w: 0.055789750069379807, 1.9971641302108765, 0.5723408460617065
# loglike =  tf.Tensor(-155.01942, shape=(), dtype=float32)
# v,a,w: 0.05413133278489113, 2.017476797103882, 0.5553111433982849
# loglike =  tf.Tensor(-154.4053, shape=(), dtype=float32)
# v,a,w: 0.05413133278489113, 2.017476797103882, 0.5553111433982849
# loglike =  tf.Tensor(-154.4053, shape=(), dtype=float32)
# v,a,w: 0.05693573132157326, 2.0394058227539062, 0.5344958305358887
# loglike =  tf.Tensor(-154.25409, shape=(), dtype=float32)
# v,a,w: 0.05693573132157326, 2.0394058227539062, 0.5344958305358887
# loglike =  tf.Tensor(-154.25409, shape=(), dtype=float32)
# v,a,w: 0.06526806205511093, 2.061617612838745, 0.5171477794647217
# loglike =  tf.Tensor(-154.52888, shape=(), dtype=float32)
# v,a,w: 0.06526806205511093, 2.061617612838745, 0.5171477794647217
# loglike =  tf.Tensor(-154.52888, shape=(), dtype=float32)
# v,a,w: 0.07989513874053955, 2.082838296890259, 0.5091245770454407
# loglike =  tf.Tensor(-154.61993, shape=(), dtype=float32)
# v,a,w: 0.07989513874053955, 2.082838296890259, 0.5091245770454407
# loglike =  tf.Tensor(-154.61993, shape=(), dtype=float32)
# v,a,w: 0.10094650089740753, 2.102093458175659, 0.512877881526947
# loglike =  tf.Tensor(-154.12218, shape=(), dtype=float32)
# v,a,w: 0.10094650089740753, 2.102093458175659, 0.512877881526947
# loglike =  tf.Tensor(-154.12218, shape=(), dtype=float32)
# v,a,w: 0.12776121497154236, 2.1188385486602783, 0.5265331864356995
# loglike =  tf.Tensor(-153.3722, shape=(), dtype=float32)
# v,a,w: 0.12776121497154236, 2.1188385486602783, 0.5265331864356995
# loglike =  tf.Tensor(-153.3722, shape=(), dtype=float32)
# v,a,w: 0.1589866578578949, 2.1328964233398438, 0.544428825378418
# loglike =  tf.Tensor(-153.04874, shape=(), dtype=float32)
# v,a,w: 0.1589866578578949, 2.1328964233398438, 0.544428825378418
# loglike =  tf.Tensor(-153.04874, shape=(), dtype=float32)
# v,a,w: 0.19290803372859955, 2.1442599296569824, 0.5590128898620605
# loglike =  tf.Tensor(-153.30234, shape=(), dtype=float32)
# v,a,w: 0.19290803372859955, 2.1442599296569824, 0.5590128898620605
# loglike =  tf.Tensor(-153.30234, shape=(), dtype=float32)
# v,a,w: 0.2279009222984314, 2.1529061794281006, 0.5635368824005127
# loglike =  tf.Tensor(-153.53656, shape=(), dtype=float32)
# v,a,w: 0.2279009222984314, 2.1529061794281006, 0.5635368824005127
# loglike =  tf.Tensor(-153.53656, shape=(), dtype=float32)
# v,a,w: 0.26284608244895935, 2.1587116718292236, 0.5546296238899231
# loglike =  tf.Tensor(-153.18924, shape=(), dtype=float32)
# v,a,w: 0.26284608244895935, 2.1587116718292236, 0.5546296238899231
# loglike =  tf.Tensor(-153.18924, shape=(), dtype=float32)
# v,a,w: 0.29734936356544495, 2.1614396572113037, 0.5336502194404602
# loglike =  tf.Tensor(-152.49585, shape=(), dtype=float32)
# v,a,w: 0.29734936356544495, 2.1614396572113037, 0.5336502194404602
# loglike =  tf.Tensor(-152.49585, shape=(), dtype=float32)
# v,a,w: 0.30868011713027954, 2.034689426422119, 0.52211594581604
# loglike =  tf.Tensor(-151.61755, shape=(), dtype=float32)
# v,a,w: 0.30868011713027954, 2.034689426422119, 0.52211594581604
# loglike =  tf.Tensor(-151.61755, shape=(), dtype=float32)
# v,a,w: 0.29657599329948425, 2.0591464042663574, 0.488455593585968
# loglike =  tf.Tensor(-151.70547, shape=(), dtype=float32)
# v,a,w: 0.29657599329948425, 2.0591464042663574, 0.488455593585968
# loglike =  tf.Tensor(-151.70547, shape=(), dtype=float32)
# v,a,w: 0.29184406995773315, 2.0811707973480225, 0.4814886152744293
# loglike =  tf.Tensor(-152.0718, shape=(), dtype=float32)
# v,a,w: 0.29184406995773315, 2.0811707973480225, 0.4814886152744293
# loglike =  tf.Tensor(-152.0718, shape=(), dtype=float32)
# v,a,w: 0.29683390259742737, 2.096524715423584, 0.5135064721107483
# loglike =  tf.Tensor(-151.56882, shape=(), dtype=float32)
# v,a,w: 0.29683390259742737, 2.096524715423584, 0.5135064721107483
# loglike =  tf.Tensor(-151.56882, shape=(), dtype=float32)
# v,a,w: 0.30455708503723145, 2.1058509349823, 0.5421886444091797
# loglike =  tf.Tensor(-152.28424, shape=(), dtype=float32)
# v,a,w: 0.30455708503723145, 2.1058509349823, 0.5421886444091797
# loglike =  tf.Tensor(-152.28424, shape=(), dtype=float32)
# v,a,w: 0.3082793056964874, 2.1099777221679688, 0.5276976227760315
# loglike =  tf.Tensor(-151.83658, shape=(), dtype=float32)
# v,a,w: 0.3082793056964874, 2.1099777221679688, 0.5276976227760315
# loglike =  tf.Tensor(-151.83658, shape=(), dtype=float32)
# v,a,w: 0.3107568323612213, 2.107362747192383, 0.4893065094947815
# loglike =  tf.Tensor(-151.87288, shape=(), dtype=float32)
# v,a,w: 0.3107568323612213, 2.107362747192383, 0.4893065094947815
# loglike =  tf.Tensor(-151.87288, shape=(), dtype=float32)
# v,a,w: 0.26585131883621216, 2.010575771331787, 0.6399402618408203
# loglike =  tf.Tensor(-162.81638, shape=(), dtype=float32)
# v,a,w: 0.26585131883621216, 2.010575771331787, 0.6399402618408203
# loglike =  tf.Tensor(-162.81638, shape=(), dtype=float32)
# v,a,w: 0.2933582365512848, 2.086493492126465, 0.4760367274284363
# loglike =  tf.Tensor(-152.32599, shape=(), dtype=float32)
# v,a,w: 0.2933582365512848, 2.086493492126465, 0.4760367274284363
# loglike =  tf.Tensor(-152.32599, shape=(), dtype=float32)
# v,a,w: 0.2908174693584442, 2.0755136013031006, 0.4888957440853119
# loglike =  tf.Tensor(-151.79886, shape=(), dtype=float32)
# v,a,w: 0.2908174693584442, 2.0755136013031006, 0.4888957440853119
# loglike =  tf.Tensor(-151.79886, shape=(), dtype=float32)
# v,a,w: 0.2902005612850189, 2.069601058959961, 0.49774980545043945
# loglike =  tf.Tensor(-151.57846, shape=(), dtype=float32)
# v,a,w: 0.2902005612850189, 2.069601058959961, 0.49774980545043945
# loglike =  tf.Tensor(-151.57846, shape=(), dtype=float32)
# v,a,w: 0.28989842534065247, 2.0635199546813965, 0.5074433088302612
# loglike =  tf.Tensor(-151.46808, shape=(), dtype=float32)
# v,a,w: 0.28989842534065247, 2.0635199546813965, 0.5074433088302612
# loglike =  tf.Tensor(-151.46808, shape=(), dtype=float32)
# v,a,w: 0.2898060977458954, 2.0573601722717285, 0.5173110365867615
# loglike =  tf.Tensor(-151.49634, shape=(), dtype=float32)
# v,a,w: 0.2898060977458954, 2.0573601722717285, 0.5173110365867615
# loglike =  tf.Tensor(-151.49634, shape=(), dtype=float32)
# v,a,w: 0.28981631994247437, 2.0512101650238037, 0.5266752243041992
# loglike =  tf.Tensor(-151.65555, shape=(), dtype=float32)
# v,a,w: 0.28981631994247437, 2.0512101650238037, 0.5266752243041992
# loglike =  tf.Tensor(-151.65555, shape=(), dtype=float32)
# v,a,w: 0.2898271083831787, 2.045153856277466, 0.5348911881446838
# loglike =  tf.Tensor(-151.90404, shape=(), dtype=float32)
# v,a,w: 0.2898271083831787, 2.045153856277466, 0.5348911881446838
# loglike =  tf.Tensor(-151.90404, shape=(), dtype=float32)
# v,a,w: 0.29541483521461487, 2.091413974761963, 0.4729136824607849
# loglike =  tf.Tensor(-152.49538, shape=(), dtype=float32)
# v,a,w: 0.29541483521461487, 2.091413974761963, 0.4729136824607849
# loglike =  tf.Tensor(-152.49538, shape=(), dtype=float32)
# v,a,w: 0.2980411946773529, 2.0958800315856934, 0.47233152389526367
# loglike =  tf.Tensor(-152.53696, shape=(), dtype=float32)
# v,a,w: 0.2980411946773529, 2.0958800315856934, 0.47233152389526367
# loglike =  tf.Tensor(-152.53696, shape=(), dtype=float32)
# v,a,w: 0.3012344539165497, 2.0998570919036865, 0.4743248522281647
# loglike =  tf.Tensor(-152.44275, shape=(), dtype=float32)
# v,a,w: 0.3012344539165497, 2.0998570919036865, 0.4743248522281647
# loglike =  tf.Tensor(-152.44275, shape=(), dtype=float32)
# v,a,w: 0.30496102571487427, 2.103328227996826, 0.47874727845191956
# loglike =  tf.Tensor(-152.242, shape=(), dtype=float32)
# v,a,w: 0.30496102571487427, 2.103328227996826, 0.47874727845191956
# loglike =  tf.Tensor(-152.242, shape=(), dtype=float32)
# v,a,w: 0.30915820598602295, 2.1062934398651123, 0.48528069257736206
# loglike =  tf.Tensor(-151.99341, shape=(), dtype=float32)
# v,a,w: 0.30915820598602295, 2.1062934398651123, 0.48528069257736206
# loglike =  tf.Tensor(-151.99341, shape=(), dtype=float32)
# v,a,w: 0.3137377202510834, 2.10876727104187, 0.4934566617012024
# loglike =  tf.Tensor(-151.76903, shape=(), dtype=float32)
# v,a,w: 0.3137377202510834, 2.10876727104187, 0.4934566617012024
# loglike =  tf.Tensor(-151.76903, shape=(), dtype=float32)
# v,a,w: 0.3185911774635315, 2.110774278640747, 0.5026883482933044
# loglike =  tf.Tensor(-151.63445, shape=(), dtype=float32)
# v,a,w: 0.3185911774635315, 2.110774278640747, 0.5026883482933044
# loglike =  tf.Tensor(-151.63445, shape=(), dtype=float32)
# v,a,w: 0.32359689474105835, 2.1123454570770264, 0.5123107433319092
# loglike =  tf.Tensor(-151.6307, shape=(), dtype=float32)
# v,a,w: 0.32359689474105835, 2.1123454570770264, 0.5123107433319092
# loglike =  tf.Tensor(-151.6307, shape=(), dtype=float32)
# v,a,w: 0.32862773537635803, 2.113513469696045, 0.5216259956359863
# loglike =  tf.Tensor(-151.76263, shape=(), dtype=float32)
# v,a,w: 0.32862773537635803, 2.113513469696045, 0.5216259956359863
# loglike =  tf.Tensor(-151.76263, shape=(), dtype=float32)
# v,a,w: 0.3335592448711395, 2.1143102645874023, 0.5299521088600159
# loglike =  tf.Tensor(-151.99715, shape=(), dtype=float32)
# v,a,w: 0.3335592448711395, 2.1143102645874023, 0.5299521088600159
# loglike =  tf.Tensor(-151.99715, shape=(), dtype=float32)
# v,a,w: 0.338277667760849, 2.1147634983062744, 0.5366708040237427
# loglike =  tf.Tensor(-152.27179, shape=(), dtype=float32)
# v,a,w: 0.338277667760849, 2.1147634983062744, 0.5366708040237427
# loglike =  tf.Tensor(-152.27179, shape=(), dtype=float32)
# v,a,w: 0.3426872491836548, 2.114895820617676, 0.5412724018096924
# loglike =  tf.Tensor(-152.51178, shape=(), dtype=float32)
# v,a,w: 0.3426872491836548, 2.114895820617676, 0.5412724018096924
# loglike =  tf.Tensor(-152.51178, shape=(), dtype=float32)
# v,a,w: 0.3467162549495697, 2.1147236824035645, 0.5433933138847351
# loglike =  tf.Tensor(-152.65082, shape=(), dtype=float32)
# v,a,w: 0.3467162549495697, 2.1147236824035645, 0.5433933138847351
# loglike =  tf.Tensor(-152.65082, shape=(), dtype=float32)
# v,a,w: 0.3503212034702301, 2.114257574081421, 0.5428435206413269
# loglike =  tf.Tensor(-152.64978, shape=(), dtype=float32)
# v,a,w: 0.3503212034702301, 2.114257574081421, 0.5428435206413269
# loglike =  tf.Tensor(-152.64978, shape=(), dtype=float32)
# v,a,w: 0.3534891903400421, 2.1135013103485107, 0.5396210551261902
# loglike =  tf.Tensor(-152.5079, shape=(), dtype=float32)
# v,a,w: 0.3534891903400421, 2.1135013103485107, 0.5396210551261902
# loglike =  tf.Tensor(-152.5079, shape=(), dtype=float32)
# v,a,w: 0.35623791813850403, 2.112452745437622, 0.5339118242263794
# loglike =  tf.Tensor(-152.2629, shape=(), dtype=float32)
# v,a,w: 0.35623791813850403, 2.112452745437622, 0.5339118242263794
# loglike =  tf.Tensor(-152.2629, shape=(), dtype=float32)
# v,a,w: 0.30202755331993103, 2.114837169647217, 0.48336702585220337
# loglike =  tf.Tensor(-152.20847, shape=(), dtype=float32)
# v,a,w: 0.30202755331993103, 2.114837169647217, 0.48336702585220337
# loglike =  tf.Tensor(-152.20847, shape=(), dtype=float32)
# v,a,w: 0.30500563979148865, 2.1270272731781006, 0.5016394257545471
# loglike =  tf.Tensor(-151.86089, shape=(), dtype=float32)
# v,a,w: 0.30500563979148865, 2.1270272731781006, 0.5016394257545471
# loglike =  tf.Tensor(-151.86089, shape=(), dtype=float32)
# v,a,w: 0.30919012427330017, 2.1364316940307617, 0.5232296586036682
# ...
#
# /tmp/ipykernel_86053/981222639.py in ?(v, a, w)
#      40     RTs_pos = tf.gather(RTs, choices_pos)
#      41     RTs_neg = tf.gather(RTs, choices_neg)
#      42
#      43     # Use tf.map_fn for parallelization within TensorFlow graph
# ---> 44     prob_pos = tf.map_fn(lambda t: rtd_density_a(t, -v, a, 1-w), RTs_pos)
#      45     prob_neg = tf.map_fn(lambda t: rtd_density_a(t, v, a, w), RTs_neg)
#      46
#      47     # Use tf.where for conditional assignment
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py in ?(*args, **kwargs)
#     656                   _call_location(), decorator_utils.get_qualified_name(func),
#     657                   func.__module__, arg_name, arg_value,
#     658                   'in a future version' if date is None else
#     659                   ('after %s' % date), instructions)
# --> 660       return func(*args, **kwargs)
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py in ?(*args, **kwargs)
#     584                 _call_location(), decorator_utils.get_qualified_name(func),
#     585                 func.__module__, arg_name,
#     586                 'in a future version' if date is None else ('after %s' % date),
#     587                 instructions)
# --> 588       return func(*args, **kwargs)
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/ops/map_fn.py in ?(fn, elems, dtype, parallel_iterations, back_prop, swap_memory, infer_shape, name, fn_output_signature)
#     633               fn_output_signature=None):
#     634   """Transform `elems` by applying `fn` to each element unstacked on axis 0."""
#     635   if fn_output_signature is None:
#     636     fn_output_signature = dtype
# --> 637   return map_fn(
#     638       fn=fn,
#     639       elems=elems,
#     640       fn_output_signature=fn_output_signature,
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py in ?(*args, **kwargs)
#     584                 _call_location(), decorator_utils.get_qualified_name(func),
#     585                 func.__module__, arg_name,
#     586                 'in a future version' if date is None else ('after %s' % date),
#     587                 instructions)
# --> 588       return func(*args, **kwargs)
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/ops/map_fn.py in ?(fn, elems, dtype, parallel_iterations, back_prop, swap_memory, infer_shape, name, fn_output_signature)
#     493           ta.write(i, value) for (ta, value) in zip(tas, result_value_batchable)
#     494       ]
#     495       return (i + 1, tas)
#     496
# --> 497     _, r_a = while_loop.while_loop(
#     498         lambda i, _: i < n,
#     499         compute, (i, result_batchable_ta),
#     500         parallel_iterations=parallel_iterations,
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/ops/while_loop.py in ?(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#     484
#     485       loop_var_structure = nest.map_structure(type_spec.type_spec_from_value,
#     486                                               list(loop_vars))
#     487       while cond(*loop_vars):
# --> 488         loop_vars = body(*loop_vars)
#     489         if try_to_pack and not isinstance(loop_vars, (list, tuple)):
#     490           packed = True
#     491           loop_vars = (loop_vars,)
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/ops/while_loop.py in ?(i, lv)
# --> 479         body = lambda i, lv: (i + 1, orig_body(*lv))
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/ops/map_fn.py in ?(i, tas)
#     483                                                         elems_flat_signature)
#     484       elems_value = elems_unflatten(elems_value_flat)
#     485       ag_ctx = autograph_ctx.control_status_ctx()
#     486       autographed_fn = autograph.tf_convert(fn, ag_ctx)
# --> 487       result_value = autographed_fn(elems_value)
#     488       nest.assert_same_structure(fn_output_signature or elems, result_value)
#     489       result_value_flat = nest.flatten(result_value)
#     490       result_value_batchable = _result_value_flat_to_batchable(
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py in ?(*args, **kwargs)
#     687           optional_features=optional_features)
#     688       try:
#     689         with conversion_ctx:
#     690           return converted_call(f, args, kwargs, options=options)
# --> 691       except Exception as e:  # pylint:disable=broad-except
#     692         if hasattr(e, 'ag_error_metadata'):
#     693           raise e.ag_error_metadata.to_exception(e)
#     694         else:
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py in ?(f, args, kwargs, caller_fn_scope, options)
#     438       if kwargs is not None:
#     439         result = converted_f(*effective_args, **kwargs)
#     440       else:
#     441         result = converted_f(*effective_args)
# --> 442     except Exception as e:
#     443       _attach_error_metadata(e, converted_f)
#     444       raise
#     445
#
# /tmp/__autograph_generated_file_wza8r2n.py in ?(t)
# ----> 8         tf__lam = lambda t: ag__.with_function_scope(lambda lscope: ag__.converted_call(rtd_density_a, (t, -v, a, 1 - w), None, lscope), 'lscope', ag__.STD)
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/autograph/core/function_wrappers.py in ?(thunk, scope_name, options)
#     110 def with_function_scope(thunk, scope_name, options):
#     111   """Inline version of the FunctionScope context manager."""
#     112   with FunctionScope('lambda_', scope_name, options) as scope:
# --> 113     return thunk(scope)
#
# /tmp/__autograph_generated_file_wza8r2n.py in ?(lscope)
# ----> 8         tf__lam = lambda t: ag__.with_function_scope(lambda lscope: ag__.converted_call(rtd_density_a, (t, -v, a, 1 - w), None, lscope), 'lscope', ag__.STD)
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py in ?(f, args, kwargs, caller_fn_scope, options)
#     438       if kwargs is not None:
#     439         result = converted_f(*effective_args, **kwargs)
#     440       else:
#     441         result = converted_f(*effective_args)
# --> 442     except Exception as e:
#     443       _attach_error_metadata(e, converted_f)
#     444       raise
#     445
#
# /tmp/__autograph_generated_filecdwop3tf.py in ?(t, v, a, w, K_max)
#      36                 sum_exp_term = ag__.Undefined('sum_exp_term')
#      37                 sum_w_term = ag__.Undefined('sum_w_term')
#      38                 sum_sine_term = ag__.Undefined('sum_sine_term')
#      39                 k_vals = ag__.Undefined('k_vals')
# ---> 40                 ag__.if_stmt(ag__.converted_call(ag__.ld(tf).greater, (ag__.ld(t), 0.25), None, fscope), if_body, else_body, get_state, set_state, ('non_sum_term', 'sum_result', 'K_max'), 2)
#      41                 density = ag__.ld(non_sum_term) * ag__.ld(sum_result)
#      42                 density = ag__.converted_call(ag__.ld(tf).where, (ag__.ld(density) <= 0, 1e-10, ag__.ld(density)), None, fscope)
#      43                 try:
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/autograph/operators/control_flow.py in ?(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1211       not used after it.
#    1212   """
#    1213   # Note: tf.cond doesn't support SparseTensor.
#    1214   if tensors.is_dense_tensor(cond):
# -> 1215     _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1216   else:
#    1217     _py_if_stmt(cond, body, orelse)
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/autograph/operators/control_flow.py in ?(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1257     if new_body_vars_[0] is not None:
#    1258       _verify_tf_cond_vars(new_body_vars_[0], new_orelse_vars, symbol_names)
#    1259     return new_orelse_vars
#    1260
# -> 1261   final_cond_vars = tf_cond.cond(
#    1262       cond, aug_body, aug_orelse, strict=True)
#    1263   final_cond_vars = final_cond_vars + init_vars[nouts:]
#    1264
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py in ?(*args, **kwargs)
#     584                 _call_location(), decorator_utils.get_qualified_name(func),
#     585                 func.__module__, arg_name,
#     586                 'in a future version' if date is None else ('after %s' % date),
#     587                 instructions)
# --> 588       return func(*args, **kwargs)
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/ops/cond.py in ?(pred, true_fn, false_fn, strict, name, fn1, fn2)
#     138   if not callable(false_fn):
#     139     raise TypeError("'false_fn' must be callable.")
#     140
#     141   if context.executing_eagerly():
# --> 142     return _eager_cond_implementation(pred, true_fn, false_fn, strict, name)
#     143
#     144   # Always enable control flow v2 if building a function, regardless of toggle.
#     145   if util.EnableControlFlowV2(ops.get_default_graph()):
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/ops/cond.py in ?(pred, true_fn, false_fn, strict, name)
#     383     with ops.name_scope(name, "cond", [pred]):
#     384       if pred_constant_value:
#     385         result = true_fn()
#     386       else:
# --> 387         result = false_fn()
#     388       if not strict:
#     389         result = _UnpackIfSingleton(result)
#     390       return result
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/autograph/operators/control_flow.py in ?()
#    1250   def aug_orelse():
#    1251     set_state(init_vars)
# -> 1252     orelse()
#    1253     new_orelse_vars = get_state()
#    1254     new_orelse_vars = new_orelse_vars[:nouts]
#    1255     new_orelse_vars_[0] = new_orelse_vars
#
# /tmp/__autograph_generated_filecdwop3tf.py in ?()
#      26                 def else_body():
#      27                     nonlocal sum_result, non_sum_term, K_max
#      28                     non_sum_term = 1 / ag__.ld(a) ** 2 * (ag__.ld(a) ** 3 / ag__.converted_call(ag__.ld(tf).sqrt, (2 * ag__.ld(np).pi * ag__.ld(t) ** 3,), None, fscope)) * ag__.converted_call(ag__.ld(tf).exp, (-ag__.ld(v) * ag__.ld(a) * ag__.ld(w) - ag__.ld(v) ** 2 * ag__.ld(t) / 2,), None, fscope)
#      29                     K_max = ag__.converted_call(ag__.ld(int), (ag__.ld(K_max) / 2,), None, fscope)
# ---> 30                     k_vals = ag__.converted_call(ag__.ld(tf).linspace, (ag__.converted_call(ag__.ld(tf).cast, (-ag__.ld(K_max), ag__.ld(tf).float32), None, fscope), ag__.converted_call(ag__.ld(tf).cast, (ag__.ld(K_max), ag__.ld(tf).float32), None, fscope), 2 * ag__.ld(K_max) + 1), None, fscope)
#      31                     sum_w_term = ag__.ld(w) + 2 * ag__.ld(k_vals)
#      32                     sum_exp_term = ag__.converted_call(ag__.ld(tf).exp, (-(ag__.ld(a) ** 2 * (ag__.ld(w) + 2 * ag__.ld(k_vals)) ** 2) / (2 * ag__.ld(t)),), None, fscope)
#      33                     sum_result = ag__.converted_call(ag__.ld(tf).reduce_sum, (ag__.ld(sum_w_term) * ag__.ld(sum_exp_term),), None, fscope)
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py in ?(f, args, kwargs, caller_fn_scope, options)
#     327     options = caller_fn_scope.callopts
#     328
#     329   if conversion.is_in_allowlist_cache(f, options):
#     330     logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331     return _call_unconverted(f, args, kwargs, options, False)
#     332
#     333   if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334     logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py in ?(f, args, kwargs, options, update_cache)
#     456     return f.__self__.call(args, kwargs)
#     457
#     458   if kwargs is not None:
#     459     return f(*args, **kwargs)
# --> 460   return f(*args)
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/ops/math_ops.py in ?(start, stop, num, name, axis)
#     218     all_tensors = (expanded_start, res, expanded_stop)
#     219     concatenated = array_ops.concat(all_tensors, axis=axis)
#     220     begin = array_ops.zeros_like(shape)
#     221     # Preserve shape information for final slice.
# --> 222     size = array_ops.concat(
#     223         (shape[0:axis], array_ops.reshape(num_int, [1]), shape[axis + 1 :]),
#     224         axis=0,
#     225     )
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/ops/array_ops.py in ?(values, axis, name)
#    1404       ops.convert_to_tensor(
#    1405           axis, name="concat_dim",
#    1406           dtype=dtypes.int32).get_shape().assert_has_rank(0)
#    1407       return identity(values[0], name=name)
# -> 1408   return gen_array_ops.concat_v2(values=values, axis=axis, name=name)
#
# ~/code/ddm_codes/venv/lib/python3.10/site-packages/tensorflow/python/ops/gen_array_ops.py in ?(values, axis, name)
#    1299         _ctx, "ConcatV2", name, values, axis)
#    1300       return _result
#    1301     except _core._NotOkStatusException as e:
#    1302       _ops.raise_from_not_ok_status(e, name)
# -> 1303     except _core._FallbackException:
#    1304       pass
#    1305     try:
#    1306       return concat_v2_eager_fallback(
#
# KeyboardInterrupt:
